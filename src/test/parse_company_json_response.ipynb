# %%
import json
import requests

headers = {'Referer': 'https://www.104.com.tw/job/ajax/content/41i1t'}
url = 'https://www.104.com.tw/company/ajax/content/bjl4o88'
'https://www.104.com.tw/company/ajax/content/bjl4o88?'
r = requests.get(url, headers=headers)
j = json.loads(r.text)

# %%
j
# Out:
# {'data': {'custSwitch': 'on',
#   'custName': '瑞嘉軟體科技股份有限公司',
#   'custNo': 25128953000,
#   'industryDesc': '電腦軟體服務業',
#   'indcat': '開發及維護大型跨國網站',
#   'empNo': '200人',
#   'capital': '暫不提供',
#   'address': '台北市內湖區內湖科技園區瑞湖街58號8樓',
#   'custLink': 'https://www.onelab.tw',
#   'profile': 'ONElab(瑞嘉軟體)為英國知名線上軟體設計集團ONEworks集團旗下在台之研發中心，集團在亞歐兩洲各設有多家子公司或研發中心，員工達數千人；集團營業獲利與成長甚佳，在全球同業中已是備受矚目的燦爛之星。2010年於台灣成立以來，我們於短時間內快速從無至有，成長至今已有近200位夥伴攜手前進。公司座落於台北內湖科技園區內，近年我們更將版圖擴張至新竹、台中等地，延攬各地研發人才，為公司的未來發展提供更強大的原動力。\r\n\r\nONElab提供尖端的軟體開發及維運能力，並憑藉著專業客制化服務，成功的透過授權將平台快速推廣至亞洲及全球，公司客戶均來自歐、美、亞等經營線上遊戲重量級企業或跨國集團，並針對客戶需求以客製化方式設計研發。 \r\n\r\nONElab深信員工不僅是公司資產，更是重要的夥伴，我們希望彼此的相處如同家人一般，我們聆聽尊重每一種聲音，同時打造方便交流及互動的開放空間，讓溝通更加輕鬆、自在，進而在其中取得共識與認同。因此採規畫性彈性上班制，工作環境比照歐美同業等級，福利甚佳，以『誠信、開放、創意、分享』為公司核心價值，並以提升夥伴幸福指數為管理目標，竭誠歡迎各路高手加入，共創更美好的未來!',
#   'product': '【一站式平台服務】\nONE Platform Provide All是瑞嘉的服務宗旨，我們憑藉著強大的軟體研發及專業整合能力，精準的滿足全球線上娛樂產業所需業務。瑞嘉人竭力協助我們的客戶站穩立足點，並領先在起跑點。\n\n【傾聽與滿足】\n瑞嘉人致力於完成全球客戶的差異化需求，根據不同的地區、市場需求，進而量身開發出的軟體，竭盡滿足客戶在瞬息萬變的網路世界所面臨的每項挑戰。\n\n【開發和維護】\n瑞嘉最引以為傲的資產，在於我們擁有一群竭力敬業的資深軟體工程師，瑞嘉人不僅在開發上大膽創新，在維護上謹慎用心，務求所有提供給客戶使用的產品，都能獲得百分百的妥善維護。\n\n【應變及風險】\n從軟體建構、測試至整合上線，瑞嘉精練的工程師夥伴，憑籍其多年的維運經驗，以確保客戶在面臨任何情形之下，皆能順利營運。致力為客戶打造零風險的營運環境。\n\n【創新與挑戰】\n在數位浪潮的推進下，新技術伴隨著新平台不停演進，瑞嘉人熱愛創新，同時也勇於挑戰，我們敏銳的資訊嗅覺以及穩定的技術能力，時刻都在為未知的挑戰待命。',
#   'welfare': '✪  本公司所聘任之正職人員得享有以下福利；工讀生/約聘人員之福利則依公司其它相關規定辦理。\n\n✪  具市場競爭力的優渥待遇 + 績效獎金(一年兩次，視年度營運及個人績效而定)。 \n•  提供具競爭力的薪資及保障年薪。\n•  年節獎金。\n•  久任獎金。\n\n✪  提供優於勞動法規的休假制度，讓員工都能充足休憩釋放壓力，也有更多時間與家人朋友相處。\n•  一年12天特休，爾後每滿一年加1天，上限30天。\n•  員工生日當月可享有生日假。\n•  員工年度健康檢查當日，可享半天健檢假。\n•  每年提供12天全薪病假。\n\n✪  提供多項補助津貼，照護員工基本生活需求。\n•  結婚禮金。\n•  生育津貼。\n•  生日禮券(金)。\n•  住院及喪葬慰問金。\n\n✪  提供周全的保險及醫療、健康等服務，關心員工健康狀態。\n•  依據法規實行勞保、健保、勞退保險制度。\n•  提供高額團體保險制度，以提高員工意外醫療保障。\n•  提供員工年度定期健康檢查。(眷屬自付健檢費，可享有與員工同等的健檢項目)\n•  健康整脊及按摩服務。\n\n✪  規劃多樣休閒活動，讓員工在參與活動之餘，更能貼近及認知公司文化。\n•  多元化的社團活動(拳擊有氧、拉丁有氧、健身活動及球類運動)。 \n•  定期舉辦慶生會(外燴或包場電影欣賞)。\n•  每季部門聚餐。\n•  年度國外旅遊。(已旅遊景點：杜拜、澳洲、法國、荷蘭、比利時、日本、沖繩、泰國、韓國、香港、峇里島、持續環遊世界中…)\n\n✪  提供一個充滿活力和人性化的美式工作環境，讓員工在工作與生活中保持平衡，樂在工作。\n•  免費供應飲料、現煮研磨咖啡、點心及水果。\n•  免費休閒娛樂設備，籃球機、撞球檯、桌球檯、按摩椅等。\n\n✪  重視夥伴們的成長與職涯學習，不定期舉辦內訓、講座課程，讓員工吸收新知，並鼓勵員工自我進修。 \n✪  規劃彈性上班時間，讓員工在上下班尖峰時間，免於塞車之苦。\n✪  凡從以下地區至本公司參加面試應徵者，提供車馬費補助：新竹以南、花蓮、台東。',
#   'management': '★ One Heart One Soul！\n    全心投注全力奉獻！\n\n★ Your Commitment Our Future！ Our Innovation Your Satisfaction！\n    你們全心付出，我們共享前途！致力創新，不負所託！',
#   'phone': '暫不提供',
#   'fax': '暫不提供',
#   'hrName': 'HR',
#   'lat': '25.074163',
#   'lon': '121.57566079999992',
#   'logo': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/logo.gif?v=20201026142926',
#   'news': '【商業週刊專訪】瑞嘉軟體科技ONElab以獨特的管理哲學，打造挑戰創新的舞台',
#   'newsLink': 'https://www.businessweekly.com.tw/business/indep/38061',
#   'zone': {'外商': '//www.104.com.tw/area/cj/foreign/searchJob'},
#   'linkMore': {'【瑞嘉】關於我們': 'http://www.onelab.tw/about.html',
#    '【瑞嘉】成長與進步': 'http://www.onelab.tw/service.html',
#    '【專訪】Cheers': 'https://www.cheers.com.tw/article/article.action?id=5094106',
#    '【專訪】商業週刊': 'https://www.businessweekly.com.tw/article.aspx?id=38061&type=Indep&utm_source=newsletter&utm_medium=email&utm_campaign=180820bw&utm_term=successstory&utm_content=pic02',
#    '【專頁】FB': 'https://www.facebook.com/ONElabTW/'},
#   'corpImage2': '',
#   'corpImage1': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/custintroduce/image1.jpg?v=20201026142926',
#   'corpImage3': '',
#   'corpLink2': '',
#   'corpLink1': 'http://www.onelab.tw/',
#   'corpLink3': '',
#   'productPictures': [],
#   'envPictures': [{'file': '962627717424538225.jpg',
#     'description': '',
#     'is_cover': 0,
#     'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424538225.jpg?v=20201026142926',
#     'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424538225.jpg?v=20201026142926'},
#    {'file': '890328564410982482.jpg',
#     'description': '',
#     'is_cover': 0,
#     'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564410982482.jpg?v=20201026142926',
#     'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564410982482.jpg?v=20201026142926'},
#    {'file': '890328564410982481.jpg',
#     'description': '',
#     'is_cover': 0,
#     'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564410982481.jpg?v=20201026142926',
#     'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564410982481.jpg?v=20201026142926'},
#    {'file': '962627717424893457.jpg',
#     'description': '',
#     'is_cover': 0,
#     'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424893457.jpg?v=20201026142926',
#     'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424893457.jpg?v=20201026142926'},
#    {'file': '890328564411355057.jpg',
#     'description': '',
#     'is_cover': 0,
#     'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564411355057.jpg?v=20201026142926',
#     'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564411355057.jpg?v=20201026142926'},
#    {'file': '962627717424893458.jpg',
#     'description': '',
#     'is_cover': 0,
#     'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424893458.jpg?v=20201026142926',
#     'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424893458.jpg?v=20201026142926'},
#    {'file': '962627717424538226.jpg',
#     'description': '',
#     'is_cover': 0,
#     'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424538226.jpg?v=20201026142926',
#     'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424538226.jpg?v=20201026142926'},
#    {'file': '890328564411355085.jpg',
#     'description': '',
#     'is_cover': 0,
#     'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564411355085.jpg?v=20201026142926',
#     'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564411355085.jpg?v=20201026142926'},
#    {'file': '890328564411354973.jpg',
#     'description': '',
#     'is_cover': 0,
#     'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564411354973.jpg?v=20201026142926',
#     'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564411354973.jpg?v=20201026142926'},
#    {'file': '962627717424893459.jpg',
#     'description': '',
#     'is_cover': 0,
#     'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424893459.jpg?v=20201026142926',
#     'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424893459.jpg?v=20201026142926'}],
#   'tagNames': ['生日假',
#    '不扣薪病假',
#    '國外旅遊',
#    '部門聚餐',
#    '慶生會',
#    '員工紅利',
#    '結婚禮金',
#    '生育津貼',
#    '停車費補助',
#    '員工進修補助',
#    '年終獎金',
#    '特殊節日獎金禮品',
#    '零食櫃',
#    '咖啡吧',
#    '員工舒壓按摩'],
#   'legalTagNames': [],
#   'historys': [],
#   'isSaved': False,
#   'isTracked': False,
#   'addrNoDesc': '台北市內湖區內湖科技園區',
#   'reportUrl': '//www.104.com.tw/question_admin/reaction.cfm?j=393a426b40463f2556583a644054361972929295a40332e2d80j57',
#   'postalCode': ''},
#  'metadata': {}}

# %%
j['metadata']
# Out:
# {}

# %%
j['data']
# Out:
# {'custSwitch': 'on',
#  'custName': '瑞嘉軟體科技股份有限公司',
#  'custNo': 25128953000,
#  'industryDesc': '電腦軟體服務業',
#  'indcat': '開發及維護大型跨國網站',
#  'empNo': '200人',
#  'capital': '暫不提供',
#  'address': '台北市內湖區內湖科技園區瑞湖街58號8樓',
#  'custLink': 'https://www.onelab.tw',
#  'profile': 'ONElab(瑞嘉軟體)為英國知名線上軟體設計集團ONEworks集團旗下在台之研發中心，集團在亞歐兩洲各設有多家子公司或研發中心，員工達數千人；集團營業獲利與成長甚佳，在全球同業中已是備受矚目的燦爛之星。2010年於台灣成立以來，我們於短時間內快速從無至有，成長至今已有近200位夥伴攜手前進。公司座落於台北內湖科技園區內，近年我們更將版圖擴張至新竹、台中等地，延攬各地研發人才，為公司的未來發展提供更強大的原動力。\r\n\r\nONElab提供尖端的軟體開發及維運能力，並憑藉著專業客制化服務，成功的透過授權將平台快速推廣至亞洲及全球，公司客戶均來自歐、美、亞等經營線上遊戲重量級企業或跨國集團，並針對客戶需求以客製化方式設計研發。 \r\n\r\nONElab深信員工不僅是公司資產，更是重要的夥伴，我們希望彼此的相處如同家人一般，我們聆聽尊重每一種聲音，同時打造方便交流及互動的開放空間，讓溝通更加輕鬆、自在，進而在其中取得共識與認同。因此採規畫性彈性上班制，工作環境比照歐美同業等級，福利甚佳，以『誠信、開放、創意、分享』為公司核心價值，並以提升夥伴幸福指數為管理目標，竭誠歡迎各路高手加入，共創更美好的未來!',
#  'product': '【一站式平台服務】\nONE Platform Provide All是瑞嘉的服務宗旨，我們憑藉著強大的軟體研發及專業整合能力，精準的滿足全球線上娛樂產業所需業務。瑞嘉人竭力協助我們的客戶站穩立足點，並領先在起跑點。\n\n【傾聽與滿足】\n瑞嘉人致力於完成全球客戶的差異化需求，根據不同的地區、市場需求，進而量身開發出的軟體，竭盡滿足客戶在瞬息萬變的網路世界所面臨的每項挑戰。\n\n【開發和維護】\n瑞嘉最引以為傲的資產，在於我們擁有一群竭力敬業的資深軟體工程師，瑞嘉人不僅在開發上大膽創新，在維護上謹慎用心，務求所有提供給客戶使用的產品，都能獲得百分百的妥善維護。\n\n【應變及風險】\n從軟體建構、測試至整合上線，瑞嘉精練的工程師夥伴，憑籍其多年的維運經驗，以確保客戶在面臨任何情形之下，皆能順利營運。致力為客戶打造零風險的營運環境。\n\n【創新與挑戰】\n在數位浪潮的推進下，新技術伴隨著新平台不停演進，瑞嘉人熱愛創新，同時也勇於挑戰，我們敏銳的資訊嗅覺以及穩定的技術能力，時刻都在為未知的挑戰待命。',
#  'welfare': '✪  本公司所聘任之正職人員得享有以下福利；工讀生/約聘人員之福利則依公司其它相關規定辦理。\n\n✪  具市場競爭力的優渥待遇 + 績效獎金(一年兩次，視年度營運及個人績效而定)。 \n•  提供具競爭力的薪資及保障年薪。\n•  年節獎金。\n•  久任獎金。\n\n✪  提供優於勞動法規的休假制度，讓員工都能充足休憩釋放壓力，也有更多時間與家人朋友相處。\n•  一年12天特休，爾後每滿一年加1天，上限30天。\n•  員工生日當月可享有生日假。\n•  員工年度健康檢查當日，可享半天健檢假。\n•  每年提供12天全薪病假。\n\n✪  提供多項補助津貼，照護員工基本生活需求。\n•  結婚禮金。\n•  生育津貼。\n•  生日禮券(金)。\n•  住院及喪葬慰問金。\n\n✪  提供周全的保險及醫療、健康等服務，關心員工健康狀態。\n•  依據法規實行勞保、健保、勞退保險制度。\n•  提供高額團體保險制度，以提高員工意外醫療保障。\n•  提供員工年度定期健康檢查。(眷屬自付健檢費，可享有與員工同等的健檢項目)\n•  健康整脊及按摩服務。\n\n✪  規劃多樣休閒活動，讓員工在參與活動之餘，更能貼近及認知公司文化。\n•  多元化的社團活動(拳擊有氧、拉丁有氧、健身活動及球類運動)。 \n•  定期舉辦慶生會(外燴或包場電影欣賞)。\n•  每季部門聚餐。\n•  年度國外旅遊。(已旅遊景點：杜拜、澳洲、法國、荷蘭、比利時、日本、沖繩、泰國、韓國、香港、峇里島、持續環遊世界中…)\n\n✪  提供一個充滿活力和人性化的美式工作環境，讓員工在工作與生活中保持平衡，樂在工作。\n•  免費供應飲料、現煮研磨咖啡、點心及水果。\n•  免費休閒娛樂設備，籃球機、撞球檯、桌球檯、按摩椅等。\n\n✪  重視夥伴們的成長與職涯學習，不定期舉辦內訓、講座課程，讓員工吸收新知，並鼓勵員工自我進修。 \n✪  規劃彈性上班時間，讓員工在上下班尖峰時間，免於塞車之苦。\n✪  凡從以下地區至本公司參加面試應徵者，提供車馬費補助：新竹以南、花蓮、台東。',
#  'management': '★ One Heart One Soul！\n    全心投注全力奉獻！\n\n★ Your Commitment Our Future！ Our Innovation Your Satisfaction！\n    你們全心付出，我們共享前途！致力創新，不負所託！',
#  'phone': '暫不提供',
#  'fax': '暫不提供',
#  'hrName': 'HR',
#  'lat': '25.074163',
#  'lon': '121.57566079999992',
#  'logo': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/logo.gif?v=20201026142926',
#  'news': '【商業週刊專訪】瑞嘉軟體科技ONElab以獨特的管理哲學，打造挑戰創新的舞台',
#  'newsLink': 'https://www.businessweekly.com.tw/business/indep/38061',
#  'zone': {'外商': '//www.104.com.tw/area/cj/foreign/searchJob'},
#  'linkMore': {'【瑞嘉】關於我們': 'http://www.onelab.tw/about.html',
#   '【瑞嘉】成長與進步': 'http://www.onelab.tw/service.html',
#   '【專訪】Cheers': 'https://www.cheers.com.tw/article/article.action?id=5094106',
#   '【專訪】商業週刊': 'https://www.businessweekly.com.tw/article.aspx?id=38061&type=Indep&utm_source=newsletter&utm_medium=email&utm_campaign=180820bw&utm_term=successstory&utm_content=pic02',
#   '【專頁】FB': 'https://www.facebook.com/ONElabTW/'},
#  'corpImage2': '',
#  'corpImage1': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/custintroduce/image1.jpg?v=20201026142926',
#  'corpImage3': '',
#  'corpLink2': '',
#  'corpLink1': 'http://www.onelab.tw/',
#  'corpLink3': '',
#  'productPictures': [],
#  'envPictures': [{'file': '962627717424538225.jpg',
#    'description': '',
#    'is_cover': 0,
#    'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424538225.jpg?v=20201026142926',
#    'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424538225.jpg?v=20201026142926'},
#   {'file': '890328564410982482.jpg',
#    'description': '',
#    'is_cover': 0,
#    'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564410982482.jpg?v=20201026142926',
#    'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564410982482.jpg?v=20201026142926'},
#   {'file': '890328564410982481.jpg',
#    'description': '',
#    'is_cover': 0,
#    'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564410982481.jpg?v=20201026142926',
#    'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564410982481.jpg?v=20201026142926'},
#   {'file': '962627717424893457.jpg',
#    'description': '',
#    'is_cover': 0,
#    'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424893457.jpg?v=20201026142926',
#    'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424893457.jpg?v=20201026142926'},
#   {'file': '890328564411355057.jpg',
#    'description': '',
#    'is_cover': 0,
#    'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564411355057.jpg?v=20201026142926',
#    'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564411355057.jpg?v=20201026142926'},
#   {'file': '962627717424893458.jpg',
#    'description': '',
#    'is_cover': 0,
#    'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424893458.jpg?v=20201026142926',
#    'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424893458.jpg?v=20201026142926'},
#   {'file': '962627717424538226.jpg',
#    'description': '',
#    'is_cover': 0,
#    'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424538226.jpg?v=20201026142926',
#    'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424538226.jpg?v=20201026142926'},
#   {'file': '890328564411355085.jpg',
#    'description': '',
#    'is_cover': 0,
#    'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564411355085.jpg?v=20201026142926',
#    'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564411355085.jpg?v=20201026142926'},
#   {'file': '890328564411354973.jpg',
#    'description': '',
#    'is_cover': 0,
#    'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564411354973.jpg?v=20201026142926',
#    'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564411354973.jpg?v=20201026142926'},
#   {'file': '962627717424893459.jpg',
#    'description': '',
#    'is_cover': 0,
#    'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424893459.jpg?v=20201026142926',
#    'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424893459.jpg?v=20201026142926'}],
#  'tagNames': ['生日假',
#   '不扣薪病假',
#   '國外旅遊',
#   '部門聚餐',
#   '慶生會',
#   '員工紅利',
#   '結婚禮金',
#   '生育津貼',
#   '停車費補助',
#   '員工進修補助',
#   '年終獎金',
#   '特殊節日獎金禮品',
#   '零食櫃',
#   '咖啡吧',
#   '員工舒壓按摩'],
#  'legalTagNames': [],
#  'historys': [],
#  'isSaved': False,
#  'isTracked': False,
#  'addrNoDesc': '台北市內湖區內湖科技園區',
#  'reportUrl': '//www.104.com.tw/question_admin/reaction.cfm?j=393a426b40463f2556583a644054361972929295a40332e2d80j57',
#  'postalCode': ''}

# %%
for k, v in j['data'].items():
    print(k, v)
# Out:
# custSwitch on
# custName 瑞嘉軟體科技股份有限公司
# custNo 25128953000
# industryDesc 電腦軟體服務業
# indcat 開發及維護大型跨國網站
# empNo 200人
# capital 暫不提供
# address 台北市內湖區內湖科技園區瑞湖街58號8樓
# custLink https://www.onelab.tw
# profile ONElab(瑞嘉軟體)為英國知名線上軟體設計集團ONEworks集團旗下在台之研發中心，集團在亞歐兩洲各設有多家子公司或研發中心，員工達數千人；集團營業獲利與成長甚佳，在全球同業中已是備受矚目的燦爛之星。2010年於台灣成立以來，我們於短時間內快速從無至有，成長至今已有近200位夥伴攜手前進。公司座落於台北內湖科技園區內，近年我們更將版圖擴張至新竹、台中等地，延攬各地研發人才，為公司的未來發展提供更強大的原動力。
#
# ONElab提供尖端的軟體開發及維運能力，並憑藉著專業客制化服務，成功的透過授權將平台快速推廣至亞洲及全球，公司客戶均來自歐、美、亞等經營線上遊戲重量級企業或跨國集團，並針對客戶需求以客製化方式設計研發。
#
# ONElab深信員工不僅是公司資產，更是重要的夥伴，我們希望彼此的相處如同家人一般，我們聆聽尊重每一種聲音，同時打造方便交流及互動的開放空間，讓溝通更加輕鬆、自在，進而在其中取得共識與認同。因此採規畫性彈性上班制，工作環境比照歐美同業等級，福利甚佳，以『誠信、開放、創意、分享』為公司核心價值，並以提升夥伴幸福指數為管理目標，竭誠歡迎各路高手加入，共創更美好的未來!
# product 【一站式平台服務】
# ONE Platform Provide All是瑞嘉的服務宗旨，我們憑藉著強大的軟體研發及專業整合能力，精準的滿足全球線上娛樂產業所需業務。瑞嘉人竭力協助我們的客戶站穩立足點，並領先在起跑點。
#
# 【傾聽與滿足】
# 瑞嘉人致力於完成全球客戶的差異化需求，根據不同的地區、市場需求，進而量身開發出的軟體，竭盡滿足客戶在瞬息萬變的網路世界所面臨的每項挑戰。
#
# 【開發和維護】
# 瑞嘉最引以為傲的資產，在於我們擁有一群竭力敬業的資深軟體工程師，瑞嘉人不僅在開發上大膽創新，在維護上謹慎用心，務求所有提供給客戶使用的產品，都能獲得百分百的妥善維護。
#
# 【應變及風險】
# 從軟體建構、測試至整合上線，瑞嘉精練的工程師夥伴，憑籍其多年的維運經驗，以確保客戶在面臨任何情形之下，皆能順利營運。致力為客戶打造零風險的營運環境。
#
# 【創新與挑戰】
# 在數位浪潮的推進下，新技術伴隨著新平台不停演進，瑞嘉人熱愛創新，同時也勇於挑戰，我們敏銳的資訊嗅覺以及穩定的技術能力，時刻都在為未知的挑戰待命。
# welfare ✪  本公司所聘任之正職人員得享有以下福利；工讀生/約聘人員之福利則依公司其它相關規定辦理。
#
# ✪  具市場競爭力的優渥待遇 + 績效獎金(一年兩次，視年度營運及個人績效而定)。
# •  提供具競爭力的薪資及保障年薪。
# •  年節獎金。
# •  久任獎金。
#
# ✪  提供優於勞動法規的休假制度，讓員工都能充足休憩釋放壓力，也有更多時間與家人朋友相處。
# •  一年12天特休，爾後每滿一年加1天，上限30天。
# •  員工生日當月可享有生日假。
# •  員工年度健康檢查當日，可享半天健檢假。
# •  每年提供12天全薪病假。
#
# ✪  提供多項補助津貼，照護員工基本生活需求。
# •  結婚禮金。
# •  生育津貼。
# •  生日禮券(金)。
# •  住院及喪葬慰問金。
#
# ✪  提供周全的保險及醫療、健康等服務，關心員工健康狀態。
# •  依據法規實行勞保、健保、勞退保險制度。
# •  提供高額團體保險制度，以提高員工意外醫療保障。
# •  提供員工年度定期健康檢查。(眷屬自付健檢費，可享有與員工同等的健檢項目)
# •  健康整脊及按摩服務。
#
# ✪  規劃多樣休閒活動，讓員工在參與活動之餘，更能貼近及認知公司文化。
# •  多元化的社團活動(拳擊有氧、拉丁有氧、健身活動及球類運動)。
# •  定期舉辦慶生會(外燴或包場電影欣賞)。
# •  每季部門聚餐。
# •  年度國外旅遊。(已旅遊景點：杜拜、澳洲、法國、荷蘭、比利時、日本、沖繩、泰國、韓國、香港、峇里島、持續環遊世界中…)
#
# ✪  提供一個充滿活力和人性化的美式工作環境，讓員工在工作與生活中保持平衡，樂在工作。
# •  免費供應飲料、現煮研磨咖啡、點心及水果。
# •  免費休閒娛樂設備，籃球機、撞球檯、桌球檯、按摩椅等。
#
# ✪  重視夥伴們的成長與職涯學習，不定期舉辦內訓、講座課程，讓員工吸收新知，並鼓勵員工自我進修。
# ✪  規劃彈性上班時間，讓員工在上下班尖峰時間，免於塞車之苦。
# ✪  凡從以下地區至本公司參加面試應徵者，提供車馬費補助：新竹以南、花蓮、台東。
# management ★ One Heart One Soul！
#     全心投注全力奉獻！
#
# ★ Your Commitment Our Future！ Our Innovation Your Satisfaction！
#     你們全心付出，我們共享前途！致力創新，不負所託！
# phone 暫不提供
# fax 暫不提供
# hrName HR
# lat 25.074163
# lon 121.57566079999992
# logo //static.104.com.tw/b_profile/cust_picture/3000/25128953000/logo.gif?v=20201026142926
# news 【商業週刊專訪】瑞嘉軟體科技ONElab以獨特的管理哲學，打造挑戰創新的舞台
# newsLink https://www.businessweekly.com.tw/business/indep/38061
# zone {'外商': '//www.104.com.tw/area/cj/foreign/searchJob'}
# linkMore {'【瑞嘉】關於我們': 'http://www.onelab.tw/about.html', '【瑞嘉】成長與進步': 'http://www.onelab.tw/service.html', '【專訪】Cheers': 'https://www.cheers.com.tw/article/article.action?id=5094106', '【專訪】商業週刊': 'https://www.businessweekly.com.tw/article.aspx?id=38061&type=Indep&utm_source=newsletter&utm_medium=email&utm_campaign=180820bw&utm_term=successstory&utm_content=pic02', '【專頁】FB': 'https://www.facebook.com/ONElabTW/'}
# corpImage2
# corpImage1 //static.104.com.tw/b_profile/cust_picture/3000/25128953000/custintroduce/image1.jpg?v=20201026142926
# corpImage3
# corpLink2
# corpLink1 http://www.onelab.tw/
# corpLink3
# productPictures []
# envPictures [{'file': '962627717424538225.jpg', 'description': '', 'is_cover': 0, 'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424538225.jpg?v=20201026142926', 'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424538225.jpg?v=20201026142926'}, {'file': '890328564410982482.jpg', 'description': '', 'is_cover': 0, 'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564410982482.jpg?v=20201026142926', 'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564410982482.jpg?v=20201026142926'}, {'file': '890328564410982481.jpg', 'description': '', 'is_cover': 0, 'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564410982481.jpg?v=20201026142926', 'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564410982481.jpg?v=20201026142926'}, {'file': '962627717424893457.jpg', 'description': '', 'is_cover': 0, 'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424893457.jpg?v=20201026142926', 'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424893457.jpg?v=20201026142926'}, {'file': '890328564411355057.jpg', 'description': '', 'is_cover': 0, 'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564411355057.jpg?v=20201026142926', 'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564411355057.jpg?v=20201026142926'}, {'file': '962627717424893458.jpg', 'description': '', 'is_cover': 0, 'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424893458.jpg?v=20201026142926', 'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424893458.jpg?v=20201026142926'}, {'file': '962627717424538226.jpg', 'description': '', 'is_cover': 0, 'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424538226.jpg?v=20201026142926', 'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424538226.jpg?v=20201026142926'}, {'file': '890328564411355085.jpg', 'description': '', 'is_cover': 0, 'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564411355085.jpg?v=20201026142926', 'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564411355085.jpg?v=20201026142926'}, {'file': '890328564411354973.jpg', 'description': '', 'is_cover': 0, 'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_890328564411354973.jpg?v=20201026142926', 'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_890328564411354973.jpg?v=20201026142926'}, {'file': '962627717424893459.jpg', 'description': '', 'is_cover': 0, 'link_l': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/l_962627717424893459.jpg?v=20201026142926', 'link_s': '//static.104.com.tw/b_profile/cust_picture/3000/25128953000/env/s_962627717424893459.jpg?v=20201026142926'}]
# tagNames ['生日假', '不扣薪病假', '國外旅遊', '部門聚餐', '慶生會', '員工紅利', '結婚禮金', '生育津貼', '停車費補助', '員工進修補助', '年終獎金', '特殊節日獎金禮品', '零食櫃', '咖啡吧', '員工舒壓按摩']
# legalTagNames []
# historys []
# isSaved False
# isTracked False
# addrNoDesc 台北市內湖區內湖科技園區
# reportUrl //www.104.com.tw/question_admin/reaction.cfm?j=393a426b40463f2556583a644054361972929295a40332e2d80j57
# postalCode

# %%
j['data'].keys()
# Out:
# dict_keys(['custSwitch', 'custName', 'custNo', 'industryDesc', 'indcat', 'empNo', 'capital', 'address', 'custLink', 'profile', 'product', 'welfare', 'management', 'phone', 'fax', 'hrName', 'lat', 'lon', 'logo', 'news', 'newsLink', 'zone', 'linkMore', 'corpImage2', 'corpImage1', 'corpImage3', 'corpLink2', 'corpLink1', 'corpLink3', 'productPictures', 'envPictures', 'tagNames', 'legalTagNames', 'historys', 'isSaved', 'isTracked', 'addrNoDesc', 'reportUrl', 'postalCode'])

# %%
j['data']['custName'] # comp_name
# Out:
# '瑞嘉軟體科技股份有限公司'

# %%
j['data']['custNo'] # comp_no
# Out:
# 25128953000

# %%
j['data']['industryDesc'] # indust_name
# Out:
# '電腦軟體服務業'

# %%
j['data']['indcat'] # indust_cat
# Out:
# '開發及維護大型跨國網站'

# %%
j['data']['empNo'] # emp_count_desc
# Out:
# '200人'

# %%
j['data']['capital'] # capital
# Out:
# '暫不提供'

# %%
j['data']['address'] # comp_addr
# Out:
# '台北市內湖區內湖科技園區瑞湖街58號8樓'

# %%
j['data']['custLink'] # comp_link
# Out:
# 'https://www.onelab.tw'

# %%
j['data']['profile'] # profile
# Out:
# 'ONElab(瑞嘉軟體)為英國知名線上軟體設計集團ONEworks集團旗下在台之研發中心，集團在亞歐兩洲各設有多家子公司或研發中心，員工達數千人；集團營業獲利與成長甚佳，在全球同業中已是備受矚目的燦爛之星。2010年於台灣成立以來，我們於短時間內快速從無至有，成長至今已有近200位夥伴攜手前進。公司座落於台北內湖科技園區內，近年我們更將版圖擴張至新竹、台中等地，延攬各地研發人才，為公司的未來發展提供更強大的原動力。\r\n\r\nONElab提供尖端的軟體開發及維運能力，並憑藉著專業客制化服務，成功的透過授權將平台快速推廣至亞洲及全球，公司客戶均來自歐、美、亞等經營線上遊戲重量級企業或跨國集團，並針對客戶需求以客製化方式設計研發。 \r\n\r\nONElab深信員工不僅是公司資產，更是重要的夥伴，我們希望彼此的相處如同家人一般，我們聆聽尊重每一種聲音，同時打造方便交流及互動的開放空間，讓溝通更加輕鬆、自在，進而在其中取得共識與認同。因此採規畫性彈性上班制，工作環境比照歐美同業等級，福利甚佳，以『誠信、開放、創意、分享』為公司核心價值，並以提升夥伴幸福指數為管理目標，竭誠歡迎各路高手加入，共創更美好的未來!'

# %%
j['data']['product'] # product
# Out:
# '【一站式平台服務】\nONE Platform Provide All是瑞嘉的服務宗旨，我們憑藉著強大的軟體研發及專業整合能力，精準的滿足全球線上娛樂產業所需業務。瑞嘉人竭力協助我們的客戶站穩立足點，並領先在起跑點。\n\n【傾聽與滿足】\n瑞嘉人致力於完成全球客戶的差異化需求，根據不同的地區、市場需求，進而量身開發出的軟體，竭盡滿足客戶在瞬息萬變的網路世界所面臨的每項挑戰。\n\n【開發和維護】\n瑞嘉最引以為傲的資產，在於我們擁有一群竭力敬業的資深軟體工程師，瑞嘉人不僅在開發上大膽創新，在維護上謹慎用心，務求所有提供給客戶使用的產品，都能獲得百分百的妥善維護。\n\n【應變及風險】\n從軟體建構、測試至整合上線，瑞嘉精練的工程師夥伴，憑籍其多年的維運經驗，以確保客戶在面臨任何情形之下，皆能順利營運。致力為客戶打造零風險的營運環境。\n\n【創新與挑戰】\n在數位浪潮的推進下，新技術伴隨著新平台不停演進，瑞嘉人熱愛創新，同時也勇於挑戰，我們敏銳的資訊嗅覺以及穩定的技術能力，時刻都在為未知的挑戰待命。'

# %%
j['data']['welfare'] # welfare
# Out:
# '✪  本公司所聘任之正職人員得享有以下福利；工讀生/約聘人員之福利則依公司其它相關規定辦理。\n\n✪  具市場競爭力的優渥待遇 + 績效獎金(一年兩次，視年度營運及個人績效而定)。 \n•  提供具競爭力的薪資及保障年薪。\n•  年節獎金。\n•  久任獎金。\n\n✪  提供優於勞動法規的休假制度，讓員工都能充足休憩釋放壓力，也有更多時間與家人朋友相處。\n•  一年12天特休，爾後每滿一年加1天，上限30天。\n•  員工生日當月可享有生日假。\n•  員工年度健康檢查當日，可享半天健檢假。\n•  每年提供12天全薪病假。\n\n✪  提供多項補助津貼，照護員工基本生活需求。\n•  結婚禮金。\n•  生育津貼。\n•  生日禮券(金)。\n•  住院及喪葬慰問金。\n\n✪  提供周全的保險及醫療、健康等服務，關心員工健康狀態。\n•  依據法規實行勞保、健保、勞退保險制度。\n•  提供高額團體保險制度，以提高員工意外醫療保障。\n•  提供員工年度定期健康檢查。(眷屬自付健檢費，可享有與員工同等的健檢項目)\n•  健康整脊及按摩服務。\n\n✪  規劃多樣休閒活動，讓員工在參與活動之餘，更能貼近及認知公司文化。\n•  多元化的社團活動(拳擊有氧、拉丁有氧、健身活動及球類運動)。 \n•  定期舉辦慶生會(外燴或包場電影欣賞)。\n•  每季部門聚餐。\n•  年度國外旅遊。(已旅遊景點：杜拜、澳洲、法國、荷蘭、比利時、日本、沖繩、泰國、韓國、香港、峇里島、持續環遊世界中…)\n\n✪  提供一個充滿活力和人性化的美式工作環境，讓員工在工作與生活中保持平衡，樂在工作。\n•  免費供應飲料、現煮研磨咖啡、點心及水果。\n•  免費休閒娛樂設備，籃球機、撞球檯、桌球檯、按摩椅等。\n\n✪  重視夥伴們的成長與職涯學習，不定期舉辦內訓、講座課程，讓員工吸收新知，並鼓勵員工自我進修。 \n✪  規劃彈性上班時間，讓員工在上下班尖峰時間，免於塞車之苦。\n✪  凡從以下地區至本公司參加面試應徵者，提供車馬費補助：新竹以南、花蓮、台東。'

# %%
j['data']['management'] # management
# Out:
# '★ One Heart One Soul！\n    全心投注全力奉獻！\n\n★ Your Commitment Our Future！ Our Innovation Your Satisfaction！\n    你們全心付出，我們共享前途！致力創新，不負所託！'

# %%
j['data']['phone']
# Out:
# '暫不提供'

# %%
j['data']['news']
# Out:
# '【商業週刊專訪】瑞嘉軟體科技ONElab以獨特的管理哲學，打造挑戰創新的舞台'

# %%
j['data']['newsLink']
# Out:
# 'https://www.businessweekly.com.tw/business/indep/38061'

# %%
j['data']['zone']
# Out:
# {'外商': '//www.104.com.tw/area/cj/foreign/searchJob'}

# %%
j['data']['tagNames']
# Out:
# ['生日假',
#  '不扣薪病假',
#  '國外旅遊',
#  '部門聚餐',
#  '慶生會',
#  '員工紅利',
#  '結婚禮金',
#  '生育津貼',
#  '停車費補助',
#  '員工進修補助',
#  '年終獎金',
#  '特殊節日獎金禮品',
#  '零食櫃',
#  '咖啡吧',
#  '員工舒壓按摩']

# %%
j['data']['legalTagNames']
# Out:
# []

# %%
j['data']['historys']
# Out:
# []

# %%
j['data']['addrNoDesc'] # comp_addr_dist
# Out:
# '台北市信義區'

# %% [markdown]
# # class

# %%
import sys
sys.path.append('..')

import re
import json
from sqlalchemy.orm import sessionmaker
from sqlalchemy import and_
from datetime import datetime
import pandas as pd
from sqlalchemy.exc import IntegrityError

from model.model import db_connect, create_table, TJobPrim, TRawCompDesc, TCompDesc

# %%
db_folder = 'db'
db_name = 'test_db.db'
DB_CONNECTION_STRING = f'sqlite:///{db_folder}/{db_name}'


class CompanyDataPreprocessor:
    
    def __init__(self):
        engine = db_connect(DB_CONNECTION_STRING)
        create_table(engine)
        self.Session = sessionmaker(bind=engine)
        
    
    def process(self):
        session = self.Session()#(expire_on_commit=False)
        
        raw_companies = session.query(TRawCompDesc).all()    
        pk_crawl_date_list = []
        pk_comp_no_list = []
        for raw_comp in raw_companies:
            pk_crawl_date_list.append(raw_comp.crawl_date)
            pk_comp_no_list.append(raw_comp.comp_no)
        session.close()
        
        for crawl_date, comp_no in zip(pk_crawl_date_list, pk_comp_no_list):
            
            raw_comp = session.query(TRawCompDesc).filter_by(crawl_date=crawl_date, comp_no=comp_no).first()
            
            crawl_date = raw_comp.crawl_date
            comp_no = raw_comp.comp_no
            
            crawled_comp_desc_json = raw_comp.comp_desc_json
            crawled_comp_desc_dict = CompDescJsonProcessor(crawled_comp_desc_json).process()
            
            
            comp_desc_dict = self._format_crawled_data_to_table_column(
                crawl_date, 
                comp_no, 
                crawled_comp_desc_dict, 
            )
            
            print(f'{crawl_date}  {comp_no}')

            try:           
                comp_desc = TCompDesc(**comp_desc_dict)
                session.add(comp_desc)
                session.commit()
                
            except IntegrityError:
                session.rollback()
                print('does not insert data, but delete raw data')
                session.delete(raw_comp)
                session.commit()
                
            except Exception as e:
                print(f'>>> Error: {e}')
                session.rollback()
                raise
                
            else:
                '''Delete raw data.'''
                print('insert data and delete raw data')
                session.delete(raw_comp)
                session.commit()
                
            finally:
                session.close()
        
        print('done')
        
        
    @staticmethod
    def _format_crawled_data_to_table_column(
            crawl_date, 
            comp_no, 
            crawled_comp_desc_dict):
        comp_desc_dict = {}
        
        comp_desc_dict = crawled_comp_desc_dict
        comp_desc_dict['crawl_date'] = crawl_date
        comp_desc_dict['comp_no'] = comp_no
        
        return comp_desc_dict

# %%
class CompDescJsonProcessor:
    
    def __init__(self, comp_desc_json: str):
        self.d = json.loads(comp_desc_json)
        
        
    def process(self):        
        d = self.d
        comp_desc_dict = {}

        comp_desc_dict['comp_name'] = d['data']['custName']
        comp_desc_dict['indust_name'] = d['data']['industryDesc']
        comp_desc_dict['indust_cat'] = d['data']['indcat']
        comp_desc_dict['emp_count_desc'] = d['data']['empNo']
        comp_desc_dict['capital'] = d['data']['capital']
        comp_desc_dict['comp_addr'] = d['data']['address']
        comp_desc_dict['comp_link'] = d['data']['custLink']
        comp_desc_dict['profile'] = remove_unicode_blank(d['data']['profile'])
        comp_desc_dict['product'] = remove_unicode_blank(d['data']['product'])
        comp_desc_dict['welfare'] = remove_unicode_blank(d['data']['welfare'])
        comp_desc_dict['management'] = remove_unicode_blank(d['data']['management'])
        comp_desc_dict['news'] = remove_unicode_blank(d['data']['news'])
        comp_desc_dict['welfare_tag'] = join_list_element(d['data']['tagNames'])
        comp_desc_dict['legal_tag'] = join_list_element(d['data']['legalTagNames'])
        comp_desc_dict['comp_addr_dist'] = d['data']['addrNoDesc']
        
        return comp_desc_dict
    
    
# utils
def join_dict_item_in_list(l: list, key: str):
    dict_item_list = [d[key] for d in l]
    return '、'.join(dict_item_list)


def join_list_element(l: list):
    return '、'.join(l)


def remove_unicode_blank(text):
    text = text.replace('\xa0', '')
    text = text.replace('\u3000', '')
    text = text.replace('\r', '')
    return text

# %%
CompanyDataPreprocessor().process()
# Out:
# >>> DB_CONNECTION_STRING: sqlite:///db/test_db.db
# 20201107  130000000127052
# insert data and delete raw data
# 20201107  130000000158860
# insert data and delete raw data
# 20201107  97311466000
# insert data and delete raw data
# 20201107  28847204000
# insert data and delete raw data
# 20201107  22798584000
# insert data and delete raw data
# 20201107  3251108000
# insert data and delete raw data
# 20201107  130000000091135
# insert data and delete raw data
# 20201107  130000000088687
# insert data and delete raw data
# 20201107  130000000148078
# insert data and delete raw data
# 20201107  130000000012043
# insert data and delete raw data
# 20201107  12868358000
# insert data and delete raw data
# 20201107  130000000131416
# insert data and delete raw data
# 20201107  21251208000
# insert data and delete raw data
# 20201107  130000000153264
# insert data and delete raw data
# 20201107  130000000129522
# insert data and delete raw data
# 20201107  86517384000
# insert data and delete raw data
# 20201107  130000000134439
# insert data and delete raw data
# 20201107  70769567000
# insert data and delete raw data
# 20201107  53342456000
# insert data and delete raw data
# 20201107  130000000155182
# insert data and delete raw data
# 20201107  46479103000
# insert data and delete raw data
# 20201107  130000000125013
# insert data and delete raw data
# 20201107  130000000156421
# insert data and delete raw data
# 20201107  130000000148908
# insert data and delete raw data
# 20201107  130000000133763
# insert data and delete raw data
# 20201107  130000000133846
# insert data and delete raw data
# 20201107  27337105000
# insert data and delete raw data
# 20201107  3374805000
# insert data and delete raw data
# 20201107  22099907000
# insert data and delete raw data
# 20201107  130000000120582
# insert data and delete raw data
# 20201107  130000000136987
# insert data and delete raw data
# 20201107  130000000093134
# insert data and delete raw data
# 20201107  130000000077684
# insert data and delete raw data
# 20201107  130000000122863
# insert data and delete raw data
# 20201107  130000000085714
# insert data and delete raw data
# 20201107  3077208000
# insert data and delete raw data
# 20201107  130000000108123
# insert data and delete raw data
# 20201107  130000000151385
# insert data and delete raw data
# 20201107  70827406000
# insert data and delete raw data
# 20201107  130000000140814
# insert data and delete raw data
# 20201107  130000000081121
# insert data and delete raw data
# 20201107  130000000116971
# insert data and delete raw data
# 20201107  130000000157484
# insert data and delete raw data
# 20201107  130000000080647
# insert data and delete raw data
# 20201107  24399985000
# insert data and delete raw data
# 20201107  130000000004942
# insert data and delete raw data
# 20201107  130000000064764
# insert data and delete raw data
# 20201107  130000000103363
# insert data and delete raw data
# 20201107  130000000126063
# insert data and delete raw data
# 20201107  130000000144551
# insert data and delete raw data
# 20201107  130000000027417
# insert data and delete raw data
# 20201107  130000000018634
# insert data and delete raw data
# 20201107  130000000137893
# insert data and delete raw data
# 20201107  80378420000
# insert data and delete raw data
# 20201107  24328949000
# insert data and delete raw data
# 20201107  27767961000
# insert data and delete raw data
# 20201107  130000000004421
# insert data and delete raw data
# 20201107  130000000151262
# insert data and delete raw data
# 20201107  130000000151101
# insert data and delete raw data
# 20201107  130000000108297
# insert data and delete raw data
# 20201107  22099287000
# insert data and delete raw data
# 20201107  16313302000
# insert data and delete raw data
# 20201107  130000000132835
# insert data and delete raw data
# 20201107  22458558000
# insert data and delete raw data
# 20201107  130000000125071
# insert data and delete raw data
# 20201107  130000000157678
# insert data and delete raw data
# 20201107  130000000155264
# insert data and delete raw data
# 20201107  16452985000
# insert data and delete raw data
# 20201107  130000000133496
# insert data and delete raw data
# 20201107  16431954000
# insert data and delete raw data
# 20201107  130000000155342
# insert data and delete raw data
# 20201107  12986518000
# insert data and delete raw data
# 20201107  3750168000
# insert data and delete raw data
# 20201107  23740225000
# insert data and delete raw data
# 20201107  130000000086218
# insert data and delete raw data
# 20201107  130000000145353
# insert data and delete raw data
# 20201107  130000000156253
# insert data and delete raw data
# 20201107  130000000079937
# insert data and delete raw data
# 20201107  130000000158114
# insert data and delete raw data
# 20201107  130000000104361
# insert data and delete raw data
# 20201107  130000000147408
# insert data and delete raw data
# 20201107  20685000000
# insert data and delete raw data
# 20201107  4967550000
# insert data and delete raw data
# 20201107  130000000072800
# insert data and delete raw data
# 20201107  130000000108932
# insert data and delete raw data
# 20201107  130000000154942
# insert data and delete raw data
# 20201107  130000000013442
# insert data and delete raw data
# 20201107  4231910004
# insert data and delete raw data
# 20201107  130000000158438
# insert data and delete raw data
# 20201107  130000000003889
# insert data and delete raw data
# 20201107  86142443000
# insert data and delete raw data
# 20201107  13136368000
# insert data and delete raw data
# 20201107  130000000041509
# insert data and delete raw data
# 20201107  130000000132716
# insert data and delete raw data
# 20201107  130000000044728
# insert data and delete raw data
# 20201107  24450379000
# insert data and delete raw data
# 20201107  130000000118809
# insert data and delete raw data
# 20201107  29149494000
# insert data and delete raw data
# 20201107  3550014000
# insert data and delete raw data
# 20201107  130000000036032
# insert data and delete raw data
# 20201107  3557017000
# insert data and delete raw data
# 20201107  16801288000
# insert data and delete raw data
# 20201107  130000000090422
# insert data and delete raw data
# 20201107  70789634000
# insert data and delete raw data
# 20201107  86519539000
# insert data and delete raw data
# 20201107  130000000155364
# insert data and delete raw data
# 20201107  130000000147221
# insert data and delete raw data
# 20201107  130000000048460
# insert data and delete raw data
# 20201107  130000000087975
# insert data and delete raw data
# 20201107  130000000158189
# insert data and delete raw data
# 20201107  130000000094495
# insert data and delete raw data
# 20201107  130000000131591
# insert data and delete raw data
# 20201107  84703052000
# insert data and delete raw data
# 20201107  4111302001
# insert data and delete raw data
# 20201107  35875366000
# insert data and delete raw data
# 20201107  24478405000
# insert data and delete raw data
# 20201107  11456006000
# insert data and delete raw data
# 20201107  80328219000
# insert data and delete raw data
# 20201107  24315156000
# insert data and delete raw data
# 20201107  3434016000
# insert data and delete raw data
# 20201107  84894313000
# insert data and delete raw data
# 20201107  130000000022883
# insert data and delete raw data
# 20201107  53023050000
# insert data and delete raw data
# 20201107  70765909000
# insert data and delete raw data
# 20201107  89283591000
# insert data and delete raw data
# 20201107  12783703000
# insert data and delete raw data
# 20201107  130000000089821
# insert data and delete raw data
# 20201107  23988289000
# insert data and delete raw data
# 20201107  94998251000
# insert data and delete raw data
# 20201107  25610177000
# insert data and delete raw data
# 20201107  130000000149156
# insert data and delete raw data
# 20201107  130000000154388
# insert data and delete raw data
# 20201107  3793407000
# insert data and delete raw data
# 20201107  130000000158533
# insert data and delete raw data
# 20201107  22039731000
# insert data and delete raw data
# 20201107  23113343000
# insert data and delete raw data
# 20201107  130000000075695
# insert data and delete raw data
# 20201107  130000000130062
# insert data and delete raw data
# 20201107  80002402000
# insert data and delete raw data
# 20201107  53179074000
# insert data and delete raw data
# 20201107  130000000147886
# insert data and delete raw data
# 20201107  130000000157202
# insert data and delete raw data
# 20201107  84443471000
# insert data and delete raw data
# 20201107  27948865000
# insert data and delete raw data
# 20201107  22822281000
# insert data and delete raw data
# 20201107  29178321000
# insert data and delete raw data
# 20201107  23131763000
# insert data and delete raw data
# 20201107  130000000143955
# insert data and delete raw data
# 20201107  62021700000
# insert data and delete raw data
# 20201107  130000000140137
# insert data and delete raw data
# 20201107  23638777000
# insert data and delete raw data
# 20201107  70817744000
# insert data and delete raw data
# 20201107  16216759000
# insert data and delete raw data
# 20201107  69408876000
# insert data and delete raw data
# 20201107  15065108000
# insert data and delete raw data
# 20201107  130000000050893
# insert data and delete raw data
# 20201107  56676244000
# insert data and delete raw data
# 20201107  23357868000
# insert data and delete raw data
# 20201107  3374707001
# insert data and delete raw data
# 20201107  130000000129181
# insert data and delete raw data
# 20201107  130000000123792
# insert data and delete raw data
# 20201107  130000000146568
# insert data and delete raw data
# 20201107  22099548000
# insert data and delete raw data
# 20201107  47067419000
# insert data and delete raw data
# 20201107  86517510000
# insert data and delete raw data
# 20201107  30826319000
# insert data and delete raw data
# 20201107  12718984000
# insert data and delete raw data
# 20201107  16094897000
# insert data and delete raw data
# 20201107  80193198000
# insert data and delete raw data
# 20201107  28990860000
# insert data and delete raw data
# 20201107  28417921000
# insert data and delete raw data
# 20201107  130000000049494
# insert data and delete raw data
# 20201107  5009788000
# insert data and delete raw data
# 20201107  14010227000
# insert data and delete raw data
# 20201107  70806514000
# insert data and delete raw data
# 20201107  3489200001
# insert data and delete raw data
# 20201107  130000000155409
# insert data and delete raw data
# 20201107  80004909000
# insert data and delete raw data
# 20201107  130000000150598
# insert data and delete raw data
# 20201107  70776547000
# insert data and delete raw data
# 20201107  130000000076803
# insert data and delete raw data
# 20201107  3435009000
# insert data and delete raw data
# 20201107  34202841000
# insert data and delete raw data
# 20201107  130000000157153
# insert data and delete raw data
# 20201107  130000000143556
# insert data and delete raw data
# 20201107  35931557000
# insert data and delete raw data
# 20201107  86517976000
# insert data and delete raw data
# 20201107  130000000096369
# insert data and delete raw data
# 20201107  130000000030440
# insert data and delete raw data
# 20201107  70781513000
# insert data and delete raw data
# 20201107  4016004000
# insert data and delete raw data
# 20201107  28958720000
# insert data and delete raw data
# 20201107  130000000077809
# insert data and delete raw data
# 20201107  27365925000
# insert data and delete raw data
# 20201107  14106686000
# insert data and delete raw data
# 20201107  13073595000
# insert data and delete raw data
# 20201107  80518512000
# insert data and delete raw data
# 20201107  84926791000
# insert data and delete raw data
# 20201107  23535435000
# insert data and delete raw data
# 20201107  130000000155176
# insert data and delete raw data
# 20201107  16834703000
# insert data and delete raw data
# 20201107  130000000067140
# insert data and delete raw data
# 20201107  13034974000
# insert data and delete raw data
# 20201107  12261768000
# insert data and delete raw data
# 20201107  3557115000
# insert data and delete raw data
# 20201107  130000000134226
# insert data and delete raw data
# 20201107  23475561000
# insert data and delete raw data
# 20201107  130000000066948
# insert data and delete raw data
# 20201107  130000000151522
# insert data and delete raw data
# 20201107  130000000083041
# insert data and delete raw data
# 20201107  30019836000
# insert data and delete raw data
# 20201107  130000000015744
# insert data and delete raw data
# 20201107  130000000082785
# insert data and delete raw data
# 20201107  86125275000
# insert data and delete raw data
# 20201107  27236155000
# insert data and delete raw data
# 20201107  55656776000
# insert data and delete raw data
# 20201107  130000000082095
# insert data and delete raw data
# 20201107  16087755000
# insert data and delete raw data
# 20201107  130000000155113
# insert data and delete raw data
# 20201107  4243562001
# insert data and delete raw data
# 20201107  130000000136231
# insert data and delete raw data
# 20201107  130000000100510
# insert data and delete raw data
# 20201107  130000000003675
# insert data and delete raw data
# 20201107  130000000144041
# insert data and delete raw data
# 20201107  130000000159050
# insert data and delete raw data
# 20201107  130000000137030
# insert data and delete raw data
# 20201107  130000000091503
# insert data and delete raw data
# 20201107  130000000141081
# insert data and delete raw data
# 20201107  4541302000
# insert data and delete raw data
# 20201107  16081507000
# insert data and delete raw data
# 20201107  27935073000
# insert data and delete raw data
# 20201107  12366616000
# insert data and delete raw data
# 20201107  28421312000
# insert data and delete raw data
# 20201107  130000000083974
# insert data and delete raw data
# 20201107  70826461000
# insert data and delete raw data
# 20201107  21222725000
# insert data and delete raw data
# 20201107  70796749000
# insert data and delete raw data
# 20201107  84445772000
# insert data and delete raw data
# 20201107  53741192000
# insert data and delete raw data
# 20201107  130000000148327
# insert data and delete raw data
# 20201107  97172648000
# insert data and delete raw data
# 20201107  130000000144257
# insert data and delete raw data
# 20201107  80329815000
# insert data and delete raw data
# 20201107  130000000140759
# insert data and delete raw data
# 20201107  23519738000
# insert data and delete raw data
# 20201107  3358805000
# insert data and delete raw data
# 20201107  130000000097473
# insert data and delete raw data
# 20201107  130000000152650
# insert data and delete raw data
# 20201107  53017509000
# insert data and delete raw data
# 20201107  23826519000
# insert data and delete raw data
# 20201107  130000000157637
# insert data and delete raw data
# 20201107  28999320000
# insert data and delete raw data
# 20201107  28426962000
# insert data and delete raw data
# 20201107  130000000107072
# insert data and delete raw data
# 20201107  130000000069331
# insert data and delete raw data
# 20201107  11099303000
# insert data and delete raw data
# 20201107  86244265000
# insert data and delete raw data
# 20201107  130000000032885
# insert data and delete raw data
# 20201107  70796826000
# insert data and delete raw data
# 20201107  23312878000
# insert data and delete raw data
# 20201107  130000000112061
# insert data and delete raw data
# 20201107  53007734000
# insert data and delete raw data
# 20201107  130000000158154
# insert data and delete raw data
# 20201107  130000000151575
# insert data and delete raw data
# 20201107  130000000157274
# insert data and delete raw data
# 20201107  130000000131454
# insert data and delete raw data
# 20201107  16832297000
# insert data and delete raw data
# 20201107  22957301000
# insert data and delete raw data
# 20201107  130000000068000
# insert data and delete raw data
# 20201107  86323471000
# insert data and delete raw data
# 20201107  70827383000
# insert data and delete raw data
# 20201107  7192904000
# insert data and delete raw data
# 20201107  130000000135977
# insert data and delete raw data
# 20201107  130000000005319
# insert data and delete raw data
# 20201107  86123662000
# insert data and delete raw data
# 20201107  130000000096230
# insert data and delete raw data
# 20201107  130000000131973
# insert data and delete raw data
# 20201107  5072925000
# insert data and delete raw data
# 20201107  70745361000
# insert data and delete raw data
# 20201107  12656354000
# insert data and delete raw data
# 20201107  130000000116679
# insert data and delete raw data
# 20201113  3374805000
# insert data and delete raw data
# 20201113  27337105000
# insert data and delete raw data
# 20201113  70769567000
# insert data and delete raw data
# 20201113  130000000153264
# insert data and delete raw data
# 20201113  16313302000
# insert data and delete raw data
# 20201113  130000000069724
# insert data and delete raw data
# 20201113  130000000155264
# insert data and delete raw data
# 20201113  130000000151262
# insert data and delete raw data
# 20201113  130000000155342
# insert data and delete raw data
# 20201113  29149494000
# insert data and delete raw data
# 20201113  130000000148078
# insert data and delete raw data
# 20201113  46479103000
# insert data and delete raw data
# 20201113  130000000125071
# insert data and delete raw data
# 20201113  130000000155409
# insert data and delete raw data
# 20201113  130000000134439
# insert data and delete raw data
# 20201113  130000000157678
# insert data and delete raw data
# 20201113  22099907000
# insert data and delete raw data
# 20201113  3750168000
# insert data and delete raw data
# 20201113  130000000133496
# insert data and delete raw data
# 20201113  53342456000
# insert data and delete raw data
# 20201113  130000000158438
# insert data and delete raw data
# 20201113  3550014000
# insert data and delete raw data
# 20201113  130000000151385
# insert data and delete raw data
# 20201113  130000000041509
# insert data and delete raw data
# 20201113  23740225000
# insert data and delete raw data
# 20201113  24399985000
# insert data and delete raw data
# 20201113  130000000081121
# insert data and delete raw data
# 20201113  130000000027417
# insert data and delete raw data
# 20201113  130000000159078
# insert data and delete raw data
# 20201113  130000000118809
# insert data and delete raw data
# 20201113  130000000108123
# insert data and delete raw data
# 20201113  130000000003889
# insert data and delete raw data
# 20201113  130000000132716
# insert data and delete raw data
# 20201113  130000000132835
# insert data and delete raw data
# 20201113  130000000116971
# insert data and delete raw data
# 20201113  80378420000
# insert data and delete raw data
# 20201113  130000000127052
# insert data and delete raw data
# 20201113  16141792000
# insert data and delete raw data
# 20201113  4967550000
# insert data and delete raw data
# 20201113  130000000091135
# insert data and delete raw data
# 20201113  28847204000
# insert data and delete raw data
# 20201113  86517384000
# insert data and delete raw data
# 20201113  12868358000
# insert data and delete raw data
# 20201113  130000000044728
# insert data and delete raw data
# 20201113  130000000012043
# insert data and delete raw data
# 20201113  130000000155182
# insert data and delete raw data
# 20201113  84900645000
# insert data and delete raw data
# 20201113  4231910004
# insert data and delete raw data
# 20201113  130000000108932
# insert data and delete raw data
# 20201113  130000000088687
# insert data and delete raw data
# 20201113  130000000144551
# insert data and delete raw data
# 20201113  130000000158114
# insert data and delete raw data
# 20201113  130000000064764
# insert data and delete raw data
# 20201113  130000000126063
# insert data and delete raw data
# 20201113  130000000013442
# insert data and delete raw data
# 20201113  130000000072800
# insert data and delete raw data
# 20201113  130000000104361
# insert data and delete raw data
# 20201113  130000000103363
# insert data and delete raw data
# 20201113  97311466000
# insert data and delete raw data
# 20201113  130000000129522
# insert data and delete raw data
# 20201113  130000000004421
# insert data and delete raw data
# 20201113  21251208000
# insert data and delete raw data
# 20201113  130000000035789
# insert data and delete raw data
# 20201113  130000000093134
# insert data and delete raw data
# 20201113  22458558000
# insert data and delete raw data
# 20201113  16452985000
# insert data and delete raw data
# 20201113  130000000131416
# insert data and delete raw data
# 20201113  12986518000
# insert data and delete raw data
# 20201113  86142443000
# insert data and delete raw data
# 20201113  130000000125013
# insert data and delete raw data
# 20201113  130000000120582
# insert data and delete raw data
# 20201113  130000000154942
# insert data and delete raw data
# 20201113  130000000156421
# insert data and delete raw data
# 20201113  130000000156253
# insert data and delete raw data
# 20201113  130000000133846
# insert data and delete raw data
# 20201113  13136368000
# insert data and delete raw data
# 20201113  130000000148908
# insert data and delete raw data
# 20201113  130000000144338
# insert data and delete raw data
# 20201113  130000000108297
# insert data and delete raw data
# 20201113  130000000133763
# insert data and delete raw data
# 20201113  130000000004942
# insert data and delete raw data
# 20201113  130000000018634
# insert data and delete raw data
# 20201113  130000000079937
# insert data and delete raw data
# 20201113  130000000137893
# insert data and delete raw data
# 20201113  130000000151101
# insert data and delete raw data
# 20201113  3077208000
# insert data and delete raw data
# 20201113  130000000158860
# insert data and delete raw data
# 20201113  22798584000
# insert data and delete raw data
# 20201113  24328949000
# insert data and delete raw data
# 20201113  24450379000
# insert data and delete raw data
# 20201113  130000000125384
# insert data and delete raw data
# 20201113  20685000000
# insert data and delete raw data
# 20201113  27767961000
# insert data and delete raw data
# 20201113  3251108000
# insert data and delete raw data
# 20201113  130000000085714
# insert data and delete raw data
# 20201113  130000000122863
# insert data and delete raw data
# 20201113  16431954000
# insert data and delete raw data
# 20201113  130000000077684
# insert data and delete raw data
# 20201113  130000000147408
# insert data and delete raw data
# 20201113  130000000145353
# insert data and delete raw data
# 20201113  130000000136987
# insert data and delete raw data
# 20201113  130000000140814
# insert data and delete raw data
# 20201113  130000000080647
# insert data and delete raw data
# 20201113  70827406000
# insert data and delete raw data
# 20201113  130000000086218
# insert data and delete raw data
# 20201113  22898991000
# insert data and delete raw data
# done
