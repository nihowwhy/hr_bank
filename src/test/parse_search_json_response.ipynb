# %%
import json
import requests

headers = {'Referer': 'https://www.104.com.tw/jobs/search/list?ro=1&jobcat=2007000000&jobcatExpansionType=0&area=6001001000&order=4&asc=1&page=2&mode=s'}
url = 'https://www.104.com.tw/jobs/search/list?ro=1&jobcat=2007000000&jobcatExpansionType=0&area=6001001000&order=4&asc=1&page=2&mode=s'
r = requests.get(url, headers=headers)
j = json.loads(r.text)

# %%
j['data']
# Out:
# {'query': {'ro': 1,
#   'jobcat': '2007000000',
#   'isnew': '',
#   'kwop': '',
#   'keyword': '',
#   'expansionType': '',
#   'excludeKeyword': '',
#   'area': '6001001000',
#   'indcat': '',
#   'expcate': '',
#   'edu': '',
#   'order': 4,
#   'asc': 1,
#   'zone': '',
#   'dep': '',
#   'dis_role': '',
#   'lang': '',
#   'sr': '',
#   'sctp': '',
#   'scmin': '',
#   'scmax': '',
#   'scstrict': '',
#   'scneg': '',
#   'excludeJobKeyword': '',
#   'excludeCompanyKeyword': '',
#   'excludeCompanyByCustno': '',
#   'excludeIndustryCat': '',
#   's9': '',
#   's5': '',
#   'wktm': '',
#   'startby': '',
#   'rostatus': '',
#   'page': 2,
#   'wf': '',
#   'jobexp': '',
#   'wt': '',
#   'mode': 's',
#   'jobsource': '',
#   'c': '',
#   'custNo': '',
#   'jobNo': '',
#   'dist': '',
#   'lat': '',
#   'lon': '',
#   'indArea': '',
#   'newZone': '',
#   'searchTempExclude': '',
#   'manage': '',
#   'showLatLon': ''},
#  'filterDesc': {'jobcat': [{'no': 2007000000, 'des': '資訊軟體系統類'}],
#   'indcat': [],
#   'area': [{'no': 6001001000, 'des': '台北市'}],
#   'dep': [],
#   'excludeIndustryCat': [],
#   'excludeCompanyByCustno': [],
#   'recommendIndcat': [{'no': '1001000000', 'des': '電子資訊 ／軟體／半導體相關業'},
#    {'no': '1002000000', 'des': '一般製造業'},
#    {'no': '1003000000', 'des': '批發／零售／傳直銷業'},
#    {'no': '1001001000', 'des': '軟體及網路相關業'},
#    {'no': '1007000000', 'des': '旅遊／休閒／運動業'}],
#   'indArea': []},
#  'queryDesc': {'ro': '全職', 'jobcat': '資訊軟體系統類', 'area': '台北市'},
#  'list': [{'jobType': '0',
#    'jobNo': '7840508',
#    'jobName': 'FPGA系統工程師',
#    'jobNameSnippet': 'FPGA系統工程師',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市南港區',
#    'jobAddress': '園區街3-2號9樓(H棟)',
#    'description': '1. 熟悉 Verilog/VHDL 設計開發語言。\r\n2. 熟悉 Xilinx Vivado 開發環境佳。',
#    'optionEdu': '學歷不拘',
#    'period': '00',
#    'periodDesc': '經歷不拘',
#    'applyCnt': '00003',
#    'applyDesc': '0~5人應徵',
#    'custNo': '130000000066724',
#    'custName': '捷揚航電股份有限公司',
#    'coIndustry': '1001003001',
#    'coIndustryDesc': '電腦及其週邊設備製造業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200909',
#    'appearDateDesc': '9/09',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '1. 熟悉 Verilog/VHDL 設計開發語言。\r\n2. 熟悉 Xilinx Vivado 開發環境佳。',
#    'tags': [],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/4o1rw?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/4o1rw?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bjesk?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': 'FPGA系統工程師',
#    'custNameRaw': '捷揚航電股份有限公司'},
#   {'jobType': '0',
#    'jobNo': '7816347',
#    'jobName': '韌體研發工程師',
#    'jobNameSnippet': '韌體研發工程師',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市南港區',
#    'jobAddress': '園區街3-2號9樓(H棟)',
#    'description': '1. 熟悉Linux系統。\r\n2. Embedded system ARM-based 韌體開發。\r\n3. 對opensource套的使用與整合有經驗。\r\n4. 演算法研究及應用(資料加密,解密,壓縮)。\r\n5. 熟悉OpenCL/OpenCV 更佳。',
#    'optionEdu': '學歷不拘',
#    'period': '03',
#    'periodDesc': '2年以上',
#    'applyCnt': '00002',
#    'applyDesc': '0~5人應徵',
#    'custNo': '130000000066724',
#    'custName': '捷揚航電股份有限公司',
#    'coIndustry': '1001003001',
#    'coIndustryDesc': '電腦及其週邊設備製造業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200909',
#    'appearDateDesc': '9/09',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '1. 熟悉Linux系統。\r\n2. Embedded system ARM-based 韌體開發。\r\n3. 對opensource套的使用與整合有經驗。\r\n4. 演算法研究及應用(資料加密,解密,壓縮)。\r\n5. 熟悉OpenCL/OpenCV 更佳。',
#    'tags': [],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/4nj4r?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/4nj4r?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bjesk?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '韌體研發工程師',
#    'custNameRaw': '捷揚航電股份有限公司'},
#   {'jobType': '2',
#    'jobNo': '7665564',
#    'jobName': '保服系統規劃人員【總公司：保服及續保部】',
#    'jobNameSnippet': '保服系統規劃人員【總公司：保服及續保部】',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市松山區',
#    'jobAddress': '敦化南路一段',
#    'description': '1.保服作業流程及系統需求改善之規劃\r\n2.新商品保服需求撰寫及測試作業\r\n3.主管交辦事項及臨時性專案支援',
#    'optionEdu': '學歷不拘',
#    'period': '04',
#    'periodDesc': '3年以上',
#    'applyCnt': '00010',
#    'applyDesc': '6~10人應徵',
#    'custNo': '80329815000',
#    'custName': '元大人壽保險股份有限公司(總公司)',
#    'coIndustry': '1004003001',
#    'coIndustryDesc': '人身保險業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200825',
#    'appearDateDesc': '8/25',
#    'optionZone': '33558528',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '1.保服作業流程及系統需求改善之規劃\r\n2.新商品保服需求撰寫及測試作業\r\n3.主管交辦事項及臨時性專案支援',
#    'tags': [],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/4kasc?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/4kasc?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/10wiapy0?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '保服系統規劃人員【總公司：保服及續保部】',
#    'custNameRaw': '元大人壽保險股份有限公司(總公司)'},
#   {'jobType': '0',
#    'jobNo': '11652899',
#    'jobName': '系統分析師',
#    'jobNameSnippet': '系統分析師',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市信義區',
#    'jobAddress': '永吉路168號6樓之1',
#    'description': '必要技術能力 : \r\n1. 三年以上系統需求訪談及系統分析經驗\r\n2. 具需求分析、系統／資料庫設計規劃能力\r\n3. 具撰寫需系統需求求訪談／規劃、規格(SRS)、系統分析規格(SA)、系統設計規格(SD)(資料庫儲存設計、程式模組設計、API設計等)、系統整合測試計畫(SIT)與測試個案(UC)等系統開發文件\r\n4. 熟悉網路系統架構規劃、系統資安規劃，能產出系統作業流程設計、資料流程設計(DFD)、資料實體關係圖(ERD)、使用案例圖(UseCase)\r\n5. 具有物件導向概念 \r\n6. 具.NET 專案開發經驗、ASP.NET MVC、Jquery/JS/CSS、MySQL 實際使用經驗\r\n7. 不排斥參與程式開發與系統程式測試與修改維護\r\n8. 整合能力強、積極尋求解決方法能力、學習意願高、自我管理良好、具備良好溝通能力、負責任、樂於團隊合作\r\n9. 能配合公司規定及完成主管交辦事項\r\n\r\n加分技術能力 :\r\n1. 了解Docker容器部署管理 \r\n2. 了解微服務架構 \r\n3. 了解雲端程式開發 \r\n4. 專案管理實務經驗',
#    'optionEdu': '學歷不拘',
#    'period': '00',
#    'periodDesc': '經歷不拘',
#    'applyCnt': '00004',
#    'applyDesc': '0~5人應徵',
#    'custNo': '80539777000',
#    'custName': '博識資訊顧問有限公司',
#    'coIndustry': '1001001002',
#    'coIndustryDesc': '電腦軟體服務業',
#    'salaryLow': '0040000',
#    'salaryHigh': '9999999',
#    'salaryDesc': '月薪40,000元以上',
#    's10': '50',
#    'appearDate': '20200912',
#    'appearDateDesc': '9/12',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '必要技術能力 : \r\n1. 三年以上系統需求訪談及系統分析經驗\r\n2. 具需求分析、系統／資料庫設計規劃能力\r\n3. 具撰寫需系統需求求訪談／規劃、規格(SRS)、系統分析規格(SA)、系統設計規格(SD)(資料庫儲存設計、程式模組設計、API設計等)、系統整合測試計畫(SIT)與測試個案(UC)等系統開發文件\r\n4. 熟悉網路系統架構規劃、系統資安規劃，能產出系統作業流程設計、資料流程設計(DFD)、資料實體關係圖(ERD)、使用案例圖(UseCase)\r\n5. 具有物件導向概念 \r\n6. 具.NET 專案開發經驗、ASP.NET MVC、Jquery/JS/CSS、MySQL 實際使用經驗\r\n7. 不排斥參與程式開發與系統程式測試與修改維護\r\n8. 整合能力強、積極尋求解決方法能力、學習意願高、自我管理良好、具備良好溝通能力、負責任、樂於團隊合作\r\n9. 能配合公司規定及完成主管交辦事項\r\n\r\n加分技術能力 :\r\n1. 了解Docker容器部署管理 \r\n2. 了解微服務架構 \r\n3. 了解雲端程式開發 \r\n4. 專案管理實務經驗',
#    'tags': ['員工20人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6xrfn?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6xrfn?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/10zzaxns?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '系統分析師',
#    'custNameRaw': '博識資訊顧問有限公司'},
#   {'jobType': '2',
#    'jobNo': '11572616',
#    'jobName': '系統整合軟體工程師 System Integration Engineer (台北)',
#    'jobNameSnippet': '系統整合軟體工程師 System Integration Engineer (台北)',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市南港區',
#    'jobAddress': '園區街3之1號11樓之1（南港軟體園區G棟）',
#    'description': '- 依據客戶及商業的需求，開發並維護高效能、高安全性、使用者易用的網站應用程式。\r\n- 整合網站應用程式至資料庫導向或 API 導向的後台系統。\r\n- 提供 24x7 的技術支援。\r\n- 開發、改善及維運所有軟體產品與基礎建設，並提供維護所需的所有必要文件。\r\n- 協助客戶排除系統整合問題與技術障礙。\r\n\r\nMUST:\r\n- C# / Java\r\n- Object-oriented programming\r\n- ASP.NET Framework / Core / Java Servlet / JSP\r\n- MySQL / T-SQL\r\n- JavaScript / jQuery and HTML\r\n- Linux or Windows Server Administration\r\n- Experience in API or website intergration (can read basic API doucument / understand HTTP status code or methods)\r\n- Any of version control software (Git, SVN, TFS)\r\n\r\nPLUS:\r\n- IIS / Tomcat / Apache / Nginx Setup and administration.\r\n- Basic networking e.g. How DNS works, internal/external network.\r\n- Understand how to deploy an application to Kubernetes, Docker or VM.\r\n- Component-based Frameworks e.g. React, Vue or Angular.\r\n- NoSQL experience e.g. Cassandra, MongoDB or Redis, etc.\r\n- Willing to answer customer’s question during non-office hour.\r\n- Able to communicate with customer in English by typing on IM.',
#    'optionEdu': '學歷不拘',
#    'period': '00',
#    'periodDesc': '經歷不拘',
#    'applyCnt': '00025',
#    'applyDesc': '11~30人應徵',
#    'custNo': '130000000030920',
#    'custName': '新加坡商鈦坦科技股份有限公司台灣分公司',
#    'coIndustry': '1001001002',
#    'coIndustryDesc': '電腦軟體服務業',
#    'salaryLow': '0055000',
#    'salaryHigh': '0075000',
#    'salaryDesc': '月薪55,000~75,000元',
#    's10': '50',
#    'appearDate': '20200915',
#    'appearDateDesc': '9/15',
#    'optionZone': '266248',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '- 依據客戶及商業的需求，開發並維護高效能、高安全性、使用者易用的網站應用程式。\r\n- 整合網站應用程式至資料庫導向或 API 導向的後台系統。\r\n- 提供 24x7 的技術支援。\r\n- 開發、改善及維運所有軟體產品與基礎建設，並提供維護所需的所有必要文件。\r\n- 協助客戶排除系統整合問題與技術障礙。\r\n\r\nMUST:\r\n- C# / Java\r\n- Object-oriented programming\r\n- ASP.NET Framework / Core / Java Servlet / JSP\r\n- MySQL / T-SQL\r\n- JavaScript / jQuery and HTML\r\n- Linux or Windows Server Administration\r\n- Experience in API or website intergration (can read basic API doucument / understand HTTP status code or methods)\r\n- Any of version control software (Git, SVN, TFS)\r\n\r\nPLUS:\r\n- IIS / Tomcat / Apache / Nginx Setup and administration.\r\n- Basic networking e.g. How DNS works, internal/external network.\r\n- Understand how to deploy an application to Kubernetes, Docker or VM.\r\n- Component-based Frameworks e.g. React, Vue or Angular.\r\n- NoSQL experience e.g. Cassandra, MongoDB or Redis, etc.\r\n- Willing to answer customer’s question during non-office hour.\r\n- Able to communicate with customer in English by typing on IM.',
#    'tags': ['外商公司', '員工280人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6w1hk?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6w1hk?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bin60?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '系統整合軟體工程師 System Integration Engineer (台北)',
#    'custNameRaw': '新加坡商鈦坦科技股份有限公司台灣分公司'},
#   {'jobType': '0',
#    'jobNo': '11569516',
#    'jobName': 'Python 電腦視覺/機器學習工程師',
#    'jobNameSnippet': 'Python 電腦視覺/機器學習工程師',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市中正區',
#    'jobAddress': '紹興北街3號9樓',
#    'description': '具影像辨識、物件偵測、物件追蹤、行為辨識、人臉辨識相關經驗\r\n熟悉任一機器學習平台\r\n熟悉OpenVino平台',
#    'optionEdu': '學歷不拘',
#    'period': '04',
#    'periodDesc': '3年以上',
#    'applyCnt': '00000',
#    'applyDesc': '0~5人應徵',
#    'custNo': '28647091000',
#    'custName': '歐拔藍數位創意有限公司',
#    'coIndustry': '1001001003',
#    'coIndustryDesc': '網際網路相關業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200621',
#    'appearDateDesc': '6/21',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '具影像辨識、物件偵測、物件追蹤、行為辨識、人臉辨識相關經驗\r\n熟悉任一機器學習平台\r\n熟悉OpenVino平台',
#    'tags': ['員工15人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6vz3g?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6vz3g?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/d5rqkvs?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': 'Python 電腦視覺/機器學習工程師',
#    'custNameRaw': '歐拔藍數位創意有限公司'},
#   {'jobType': '0',
#    'jobNo': '11592476',
#    'jobName': '運維工程師(內湖)',
#    'jobNameSnippet': '運維工程師(內湖)',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市內湖區',
#    'jobAddress': '',
#    'description': '服務器日常監控和維護、線上環境搭建、攻擊防護和日誌分析、代碼發佈、處理網站卡頓以及提升網站的訪問速度等等。',
#    'optionEdu': '學歷不拘',
#    'period': '00',
#    'periodDesc': '經歷不拘',
#    'applyCnt': '00001',
#    'applyDesc': '0~5人應徵',
#    'custNo': '130000000142970',
#    'custName': '寰娛數位科技有限公司',
#    'coIndustry': '1001001002',
#    'coIndustryDesc': '電腦軟體服務業',
#    'salaryLow': '0034000',
#    'salaryHigh': '0060000',
#    'salaryDesc': '月薪34,000~60,000元',
#    's10': '50',
#    'appearDate': '20200707',
#    'appearDateDesc': '7/07',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '服務器日常監控和維護、線上環境搭建、攻擊防護和日誌分析、代碼發佈、處理網站卡頓以及提升網站的訪問速度等等。',
#    'tags': ['員工30人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6wgt8?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6wgt8?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bl1mi?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '運維工程師(內湖)',
#    'custNameRaw': '寰娛數位科技有限公司'},
#   {'jobType': '0',
#    'jobNo': '11599714',
#    'jobName': '資深醫療軟體研發工程師',
#    'jobNameSnippet': '資深醫療軟體研發工程師',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市中山區',
#    'jobAddress': '復興北路166號10樓',
#    'description': '.國內醫療軟體市佔最大(合約近6000)廠商,客群(中西牙藥檢醫美長照居家..)廣。\r\n.目前已有多項產品於Azure營運以及相關APP，具國內外SaaS經營實例。\r\n.既可學習醫療基礎知識、需求、亦可熟悉多樣開發工具\r\n其主要職務如下:\r\n1.醫療軟體系統研發維護(Foxpro、C#、Javascript)。\r\n2.WinBase、雲端與APP團隊輪調。',
#    'optionEdu': '學歷不拘',
#    'period': '00',
#    'periodDesc': '經歷不拘',
#    'applyCnt': '00000',
#    'applyDesc': '0~5人應徵',
#    'custNo': '70544104000',
#    'custName': '展望亞洲科技股份有限公司',
#    'coIndustry': '1001001002',
#    'coIndustryDesc': '電腦軟體服務業',
#    'salaryLow': '0040000',
#    'salaryHigh': '0100000',
#    'salaryDesc': '月薪40,000~100,000元',
#    's10': '50',
#    'appearDate': '20200921',
#    'appearDateDesc': '9/21',
#    'optionZone': '512',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '.國內醫療軟體市佔最大(合約近6000)廠商,客群(中西牙藥檢醫美長照居家..)廣。\r\n.目前已有多項產品於Azure營運以及相關APP，具國內外SaaS經營實例。\r\n.既可學習醫療基礎知識、需求、亦可熟悉多樣開發工具\r\n其主要職務如下:\r\n1.醫療軟體系統研發維護(Foxpro、C#、Javascript)。\r\n2.WinBase、雲端與APP團隊輪調。',
#    'tags': ['員工100人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6wmea?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6wmea?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/weo4z0g?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '資深醫療軟體研發工程師',
#    'custNameRaw': '展望亞洲科技股份有限公司'},
#   {'jobType': '0',
#    'jobNo': '11684994',
#    'jobName': '平台工程師',
#    'jobNameSnippet': '平台工程師',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市內湖區',
#    'jobAddress': '',
#    'description': '\t职位描述：\r\n1、解答回覆商戶串接問題\r\n2、完成相关技术文档的编写\r\n3、支援遊戲API實作\r\n4、完成專案進度\r\n\r\n职位要求：\r\n1、熟悉API撰寫(.net , php , nodejs 等..)\r\n2、熟悉軟體架構(三層式架構)\r\n3、熟悉效能優化架構與撰寫\r\n4、高EQ , 良好溝通應對\r\n\r\n福利\r\n1、13薪\r\n2、績效獎金(依公司營運狀況)\r\n3、不定期聚餐\r\n4、彈性上班\r\n5、年度健康檢查',
#    'optionEdu': '學歷不拘',
#    'period': '02',
#    'periodDesc': '1年以上',
#    'applyCnt': '00000',
#    'applyDesc': '0~5人應徵',
#    'custNo': '130000000148327',
#    'custName': '智谷系統有限公司',
#    'coIndustry': '1001001001',
#    'coIndustryDesc': '電腦系統整合服務業',
#    'salaryLow': '0028000',
#    'salaryHigh': '0038000',
#    'salaryDesc': '月薪28,000~38,000元',
#    's10': '50',
#    'appearDate': '20200903',
#    'appearDateDesc': '9/03',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '\t职位描述：\r\n1、解答回覆商戶串接問題\r\n2、完成相关技术文档的编写\r\n3、支援遊戲API實作\r\n4、完成專案進度\r\n\r\n职位要求：\r\n1、熟悉API撰寫(.net , php , nodejs 等..)\r\n2、熟悉軟體架構(三層式架構)\r\n3、熟悉效能優化架構與撰寫\r\n4、高EQ , 良好溝通應對\r\n\r\n福利\r\n1、13薪\r\n2、績效獎金(依公司營運狀況)\r\n3、不定期聚餐\r\n4、彈性上班\r\n5、年度健康檢查',
#    'tags': [],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6yg76?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6yg76?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bl5rb?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '平台工程師',
#    'custNameRaw': '智谷系統有限公司'},
#   {'jobType': '2',
#    'jobNo': '11607837',
#    'jobName': '前端工程師(系統整合部)',
#    'jobNameSnippet': '前端工程師(系統整合部)',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市內湖區',
#    'jobAddress': '',
#    'description': '【工作職責】\n1. 負責網站前端開發工作，使用Ajax與後臺資料進行API串接\n2. 參與產品UI/UX設計，並負責將prototype轉化為實體網站\n3. 將使用者體驗放在第一位，與UI/UX designer協作，開發出兼具美感與可用性的網站\n4. 經常性跨部門溝通，交付符合User需求的產品\n\n【必備技能】\n1. 2年以上網頁開發相關工作經驗\n2. 熟悉HTML、CSS、SASS、Javascript、JQuery、Bootstrap經驗\n3. 具備良好網頁切版能力， 能處理跨瀏覽器及跨裝置(RWD)的網頁\n4. 對頁面開發有熱情，工作細心負責、具備良好的思考邏輯\n5. 具備獨立開發的能力，且擅長溝通及團隊合作\n\n【加分條件】\n1. 性格樂觀開朗，積極主動，富有責任感\n2. 跨界UI/UX設計經驗者優先考慮\n3. 熟悉Angular、Vue、React 擇一框架經驗者佳\n4. 熟悉網頁互動效果者佳\n5. 熟悉 NPM, Webpack 自動化工具者佳\n\n【職場優勢】\n1. 友善的職場環境，同事間傾囊相授，互相分享開發技術\n2. 進修工作相關外部專業課程，有機會申請部門全額學費補助\n3. 每周部門羽球活動，消除卡路里，同時增進同事情誼',
#    'optionEdu': '學歷不拘',
#    'period': '03',
#    'periodDesc': '2年以上',
#    'applyCnt': '00001',
#    'applyDesc': '0~5人應徵',
#    'custNo': '27935073000',
#    'custName': '富邦人壽保險股份有限公司(總公司)',
#    'coIndustry': '1004003001',
#    'coIndustryDesc': '人身保險業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200916',
#    'appearDateDesc': '9/16',
#    'optionZone': '2101888',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '【工作職責】\n1. 負責網站前端開發工作，使用Ajax與後臺資料進行API串接\n2. 參與產品UI/UX設計，並負責將prototype轉化為實體網站\n3. 將使用者體驗放在第一位，與UI/UX designer協作，開發出兼具美感與可用性的網站\n4. 經常性跨部門溝通，交付符合User需求的產品\n\n【必備技能】\n1. 2年以上網頁開發相關工作經驗\n2. 熟悉HTML、CSS、SASS、Javascript、JQuery、Bootstrap經驗\n3. 具備良好網頁切版能力， 能處理跨瀏覽器及跨裝置(RWD)的網頁\n4. 對頁面開發有熱情，工作細心負責、具備良好的思考邏輯\n5. 具備獨立開發的能力，且擅長溝通及團隊合作\n\n【加分條件】\n1. 性格樂觀開朗，積極主動，富有責任感\n2. 跨界UI/UX設計經驗者優先考慮\n3. 熟悉Angular、Vue、React 擇一框架經驗者佳\n4. 熟悉網頁互動效果者佳\n5. 熟悉 NPM, Webpack 自動化工具者佳\n\n【職場優勢】\n1. 友善的職場環境，同事間傾囊相授，互相分享開發技術\n2. 進修工作相關外部專業課程，有機會申請部門全額學費補助\n3. 每周部門羽球活動，消除卡路里，同時增進同事情誼',
#    'tags': ['員工28700人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6wsnx?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6wsnx?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/ctztka0?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '前端工程師(系統整合部)',
#    'custNameRaw': '富邦人壽保險股份有限公司(總公司)'},
#   {'jobType': '0',
#    'jobNo': '11614878',
#    'jobName': 'Front-End-Engineer 前端工程師 (網路電商)',
#    'jobNameSnippet': 'Front-End-Engineer 前端工程師 (網路電商)',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市內湖區',
#    'jobAddress': '瑞光路188巷52號3樓',
#    'description': '歡迎對金融科技 / 數據應用 有興趣或相關經驗人才加入!\r\n\r\n[ 職務說明 ] \r\n- 與UI/UX Designers、後端工程師與PM協作\r\n- 負責系統前端開發工作，開發RWD網頁前端互動\r\n- 維護與優化前端既有功能\r\n- 串接後端 API 資料\r\n- 勇於學習新的程式語言及開發流程 \r\n\r\n[ 技術條件 (必備) ] \r\n- 熟悉 HTML、CSS、JavaScript\r\n- 熟悉 CSS框架， 能建置RWD網頁，例如：Bootstrap\r\n- 熟悉前端框架 Vue\r\n- 串接後端API\r\n\r\n[ 其他加分項目 (有經驗者加分) ] \r\n- 有UI/UX設計經驗\r\n- 攜帶作品集或展示\r\n- 對前端畫面的要求高，一點都不馬虎\r\n\r\n[ 福利 ] \r\n正職皆享有以下：\r\n「上 班 時 間」：彈性上班時間\r\n「休 假 福 利」：週休二日、年假 \r\n「保 險 福 利」：勞保、健保、勞退提撥金 \r\n「獎 金 福 利」：年終獎金、三節獎金\r\n「其 他 福 利」：公司聚餐 、員工旅遊、調薪、免費零食飲料',
#    'optionEdu': '學歷不拘',
#    'period': '00',
#    'periodDesc': '經歷不拘',
#    'applyCnt': '00010',
#    'applyDesc': '6~10人應徵',
#    'custNo': '130000000124107',
#    'custName': '愷恩科技股份有限公司',
#    'coIndustry': '1001001005',
#    'coIndustryDesc': '數位內容產業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200918',
#    'appearDateDesc': '9/18',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '歡迎對金融科技 / 數據應用 有興趣或相關經驗人才加入!\r\n\r\n[ 職務說明 ] \r\n- 與UI/UX Designers、後端工程師與PM協作\r\n- 負責系統前端開發工作，開發RWD網頁前端互動\r\n- 維護與優化前端既有功能\r\n- 串接後端 API 資料\r\n- 勇於學習新的程式語言及開發流程 \r\n\r\n[ 技術條件 (必備) ] \r\n- 熟悉 HTML、CSS、JavaScript\r\n- 熟悉 CSS框架， 能建置RWD網頁，例如：Bootstrap\r\n- 熟悉前端框架 Vue\r\n- 串接後端API\r\n\r\n[ 其他加分項目 (有經驗者加分) ] \r\n- 有UI/UX設計經驗\r\n- 攜帶作品集或展示\r\n- 對前端畫面的要求高，一點都不馬虎\r\n\r\n[ 福利 ] \r\n正職皆享有以下：\r\n「上 班 時 間」：彈性上班時間\r\n「休 假 福 利」：週休二日、年假 \r\n「保 險 福 利」：勞保、健保、勞退提撥金 \r\n「獎 金 福 利」：年終獎金、三節獎金\r\n「其 他 福 利」：公司聚餐 、員工旅遊、調薪、免費零食飲料',
#    'tags': [],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6wy3i?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6wy3i?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bkn2j?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': 'Front-End-Engineer 前端工程師 (網路電商)',
#    'custNameRaw': '愷恩科技股份有限公司'},
#   {'jobType': '0',
#    'jobNo': '11671260',
#    'jobName': '科服處-API工程師',
#    'jobNameSnippet': '科服處-API工程師',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市中山區',
#    'jobAddress': '長安東路二段162號2樓',
#    'description': '工作內容：\n1. API 程式維護、程式改版、版本管理\n2. 客戶API對接作業所需的溝通、測試作業\n3. 線上隨時配合專案需求，進行API對接測試\n4. 支援科技服務處各項營運改善所需的開發協助\n5. 自律性強、自主性高、獨當一面掌握業務洽談\n\n我們秉持開放和鼓勵創新，等你來挑戰！！！\n\n----------------------------\n福利制度\n1. 勞工保險\n2. 全民健康保險\n3. 職災各類保險\n4. 勞工退休金\n5. 團隊獎金\n6. 員工婚喪喜慶補助\n7. 員工健康檢查補助\n8. 員工子女獎學金\n9. 年度旅遊、生日禮金\n10. 績效獎金\n11. 節日禮品\n12. 完善培訓計劃與暢通升遷管道',
#    'optionEdu': '學歷不拘',
#    'period': '04',
#    'periodDesc': '3年以上',
#    'applyCnt': '00000',
#    'applyDesc': '0~5人應徵',
#    'custNo': '16042250000',
#    'custName': '全球快遞_全球商務科技股份有限公司',
#    'coIndustry': '1010003002',
#    'coIndustryDesc': '快遞服務業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200917',
#    'appearDateDesc': '9/17',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '工作內容：\n1. API 程式維護、程式改版、版本管理\n2. 客戶API對接作業所需的溝通、測試作業\n3. 線上隨時配合專案需求，進行API對接測試\n4. 支援科技服務處各項營運改善所需的開發協助\n5. 自律性強、自主性高、獨當一面掌握業務洽談\n\n我們秉持開放和鼓勵創新，等你來挑戰！！！\n\n----------------------------\n福利制度\n1. 勞工保險\n2. 全民健康保險\n3. 職災各類保險\n4. 勞工退休金\n5. 團隊獎金\n6. 員工婚喪喜慶補助\n7. 員工健康檢查補助\n8. 員工子女獎學金\n9. 年度旅遊、生日禮金\n10. 績效獎金\n11. 節日禮品\n12. 完善培訓計劃與暢通升遷管道',
#    'tags': ['員工330人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6y5lo?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6y5lo?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/7db53bk?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '科服處-API工程師',
#    'custNameRaw': '全球快遞_全球商務科技股份有限公司'},
#   {'jobType': '0',
#    'jobNo': '11707062',
#    'jobName': 'MIS 工程師(台北市信義區)',
#    'jobNameSnippet': 'MIS 工程師(台北市信義區)',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市信義區',
#    'jobAddress': '',
#    'description': '1. 維護MIS系統的功能，以符合企業需求。\r\n2. User電腦軟硬體的故障排除。\r\n3. 防火牆架設管理\r\n4. 公司電腦及網路(防火牆與VPN)及電話交換主機相關軟硬體之維護\r\n5. Ｗeb、Mail、AD、Proxy、VMware等Server架設、維護、管理\r\n6. 駐點於外商國際知名精品業公司(台北市信義區)\r\n7. 有外商公司經驗三年以上',
#    'optionEdu': '學歷不拘',
#    'period': '04',
#    'periodDesc': '3年以上',
#    'applyCnt': '00008',
#    'applyDesc': '6~10人應徵',
#    'custNo': '130000000152045',
#    'custName': '新科有限公司',
#    'coIndustry': '1001001003',
#    'coIndustryDesc': '網際網路相關業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200909',
#    'appearDateDesc': '9/09',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '1. 維護MIS系統的功能，以符合企業需求。\r\n2. User電腦軟硬體的故障排除。\r\n3. 防火牆架設管理\r\n4. 公司電腦及網路(防火牆與VPN)及電話交換主機相關軟硬體之維護\r\n5. Ｗeb、Mail、AD、Proxy、VMware等Server架設、維護、管理\r\n6. 駐點於外商國際知名精品業公司(台北市信義區)\r\n7. 有外商公司經驗三年以上',
#    'tags': [],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6yx86?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6yx86?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bl8ml?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': 'MIS 工程師(台北市信義區)',
#    'custNameRaw': '新科有限公司'},
#   {'jobType': '0',
#    'jobNo': '11703003',
#    'jobName': '前端開發工程師 Web Developer',
#    'jobNameSnippet': '前端開發工程師 Web Developer',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市中山區',
#    'jobAddress': '長安東路二段178號5樓',
#    'description': 'Duties\r\n\r\nDevelop and enhance online platform and E-commerce website\r\nLaunch daily promotional campaigns on the web\r\nWork with the Marketing Dept. closely to enhance the existing applications\r\nTroubleshoot errors effectively and efficiently\r\n\r\nRequirement\r\n\r\nDiploma in Computer Science, Information Technology or equivalent preferred\r\nAt least 1 year of relevant experience in web development and E-commerce platform \r\nExperience in the e-commerce industry is an advantage\r\nHands-on experience in web application development, preferably in .NET stack: C# / SQL\r\nKnowledge in HTML5, CSS, and JavaScript\r\nFast learner, a strong sense of responsibility and self-motivated\r\nCan work at home\r\nSalary negotiable\r\n',
#    'optionEdu': '學歷不拘',
#    'period': '02',
#    'periodDesc': '1年以上',
#    'applyCnt': '00000',
#    'applyDesc': '0~5人應徵',
#    'custNo': '130000000151910',
#    'custName': '創科軟件有限公司',
#    'coIndustry': '1001001002',
#    'coIndustryDesc': '電腦軟體服務業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200819',
#    'appearDateDesc': '8/19',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': 'Duties\r\n\r\nDevelop and enhance online platform and E-commerce website\r\nLaunch daily promotional campaigns on the web\r\nWork with the Marketing Dept. closely to enhance the existing applications\r\nTroubleshoot errors effectively and efficiently\r\n\r\nRequirement\r\n\r\nDiploma in Computer Science, Information Technology or equivalent preferred\r\nAt least 1 year of relevant experience in web development and E-commerce platform \r\nExperience in the e-commerce industry is an advantage\r\nHands-on experience in web application development, preferably in .NET stack: C# / SQL\r\nKnowledge in HTML5, CSS, and JavaScript\r\nFast learner, a strong sense of responsibility and self-motivated\r\nCan work at home\r\nSalary negotiable\r\n',
#    'tags': ['員工1人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6yu3f?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6yu3f?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bl8iu?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '前端開發工程師 Web Developer',
#    'custNameRaw': '創科軟件有限公司'},
#   {'jobType': '2',
#    'jobNo': '11709769',
#    'jobName': '程式設計師(資訊部)',
#    'jobNameSnippet': '程式設計師(資訊部)',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市大同區',
#    'jobAddress': '',
#    'description': '1.理財e管家、法人部APP\r\n2.證券期貨下單相關功能開發\r\n3.程式維護',
#    'optionEdu': '學歷不拘',
#    'period': '04',
#    'periodDesc': '3年以上',
#    'applyCnt': '00000',
#    'applyDesc': '0~5人應徵',
#    'custNo': '23535744000',
#    'custName': '國票綜合證券股份有限公司',
#    'coIndustry': '1004002002',
#    'coIndustryDesc': '證券及期貨業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200915',
#    'appearDateDesc': '9/15',
#    'optionZone': '4096',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '1.理財e管家、法人部APP\r\n2.證券期貨下單相關功能開發\r\n3.程式維護',
#    'tags': ['員工1056人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6yzbd?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6yzbd?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/at8koao?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '程式設計師(資訊部)',
#    'custNameRaw': '國票綜合證券股份有限公司'},
#   {'jobType': '2',
#    'jobNo': '11709775',
#    'jobName': '程式設計師(資訊部)',
#    'jobNameSnippet': '程式設計師(資訊部)',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市大同區',
#    'jobAddress': '',
#    'description': '1.理財e管家、法人部APP\r\n2.證券期貨下單相關功能開發\r\n3.程式維護',
#    'optionEdu': '學歷不拘',
#    'period': '04',
#    'periodDesc': '3年以上',
#    'applyCnt': '00001',
#    'applyDesc': '0~5人應徵',
#    'custNo': '23535744000',
#    'custName': '國票綜合證券股份有限公司',
#    'coIndustry': '1004002002',
#    'coIndustryDesc': '證券及期貨業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200915',
#    'appearDateDesc': '9/15',
#    'optionZone': '4096',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '1.理財e管家、法人部APP\r\n2.證券期貨下單相關功能開發\r\n3.程式維護',
#    'tags': ['員工1056人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6yzbj?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6yzbj?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/at8koao?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '程式設計師(資訊部)',
#    'custNameRaw': '國票綜合證券股份有限公司'},
#   {'jobType': '0',
#    'jobNo': '11704616',
#    'jobName': '遊戲 CLIENT 端開發主管',
#    'jobNameSnippet': '遊戲 CLIENT 端開發主管',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市信義區',
#    'jobAddress': '松德路171號5樓之3',
#    'description': '1. Client 端遊戲程式開發與維護，熟悉 Unity 開發，Lua 程式佳。\r\n\r\n2. 負責 Unity 手遊客戶端技術框架設計，核心功能的邏輯代碼開發實現，對研發專案的交付時間和品質負責。\r\n\r\n3. 具有五年以上開發過 2D/3D 多人連線遊戲的經驗。\r\n\r\n4. 與專案成員合作溝通，有管理團隊的經驗。\r\n\r\n5. 有編輯器開發經驗尤佳。',
#    'optionEdu': '學歷不拘',
#    'period': '06',
#    'periodDesc': '5年以上',
#    'applyCnt': '00001',
#    'applyDesc': '0~5人應徵',
#    'custNo': '130000000149404',
#    'custName': '有樂資訊有限公司',
#    'coIndustry': '1001001002',
#    'coIndustryDesc': '電腦軟體服務業',
#    'salaryLow': '0070000',
#    'salaryHigh': '0120000',
#    'salaryDesc': '月薪70,000~120,000元',
#    's10': '50',
#    'appearDate': '20200914',
#    'appearDateDesc': '9/14',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '1. Client 端遊戲程式開發與維護，熟悉 Unity 開發，Lua 程式佳。\r\n\r\n2. 負責 Unity 手遊客戶端技術框架設計，核心功能的邏輯代碼開發實現，對研發專案的交付時間和品質負責。\r\n\r\n3. 具有五年以上開發過 2D/3D 多人連線遊戲的經驗。\r\n\r\n4. 與專案成員合作溝通，有管理團隊的經驗。\r\n\r\n5. 有編輯器開發經驗尤佳。',
#    'tags': [],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6yvc8?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6yvc8?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bl6l8?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '遊戲 CLIENT 端開發主管',
#    'custNameRaw': '有樂資訊有限公司'},
#   {'jobType': '0',
#    'jobNo': '11625067',
#    'jobName': '資訊助理',
#    'jobNameSnippet': '資訊助理',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市萬華區',
#    'jobAddress': '大理街175巷27號(近龍山寺捷運站)',
#    'description': '1.負責一般文書資料處理及歸檔工作，協助處理庶務性行政工作。\n2.具電腦組裝能力。\n3.資訊設備、環境的維護及修繕。\n4.院區同仁資訊相關問題的排解，優化。\n5.電話接聽、訪客接待。\n6.主管交辦事項。\n',
#    'optionEdu': '學歷不拘',
#    'period': '00',
#    'periodDesc': '經歷不拘',
#    'applyCnt': '00021',
#    'applyDesc': '11~30人應徵',
#    'custNo': '3772402000',
#    'custName': '財團法人台北市私立愛愛院',
#    'coIndustry': '1012001004',
#    'coIndustryDesc': '其他醫療保健服務業',
#    'salaryLow': '0027000',
#    'salaryHigh': '0032000',
#    'salaryDesc': '月薪27,000~32,000元',
#    's10': '50',
#    'appearDate': '20200916',
#    'appearDateDesc': '9/16',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '1.負責一般文書資料處理及歸檔工作，協助處理庶務性行政工作。\n2.具電腦組裝能力。\n3.資訊設備、環境的維護及修繕。\n4.院區同仁資訊相關問題的排解，優化。\n5.電話接聽、訪客接待。\n6.主管交辦事項。\n',
#    'tags': ['員工130人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6x5yj?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6x5yj?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1qdzo0g?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': '資訊助理',
#    'custNameRaw': '財團法人台北市私立愛愛院'},
#   {'jobType': '0',
#    'jobNo': '11625263',
#    'jobName': 'Oracle資料庫設計工程師',
#    'jobNameSnippet': 'Oracle資料庫設計工程師',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市信義區',
#    'jobAddress': '',
#    'description': '主要工作內容，維護開發既有的 團險/旅平險/原國華系統。',
#    'optionEdu': '學歷不拘',
#    'period': '00',
#    'periodDesc': '經歷不拘',
#    'applyCnt': '00003',
#    'applyDesc': '0~5人應徵',
#    'custNo': '130000000129954',
#    'custName': '翰霖科技資訊股份有限公司',
#    'coIndustry': '1001001005',
#    'coIndustryDesc': '數位內容產業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200921',
#    'appearDateDesc': '9/21',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '主要工作內容，維護開發既有的 團險/旅平險/原國華系統。',
#    'tags': ['員工60人'],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6x63z?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6x63z?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bkrky?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': 'Oracle資料庫設計工程師',
#    'custNameRaw': '翰霖科技資訊股份有限公司'},
#   {'jobType': '0',
#    'jobNo': '11643931',
#    'jobName': 'Vue 前端工程師 Front-end Engineer',
#    'jobNameSnippet': 'Vue 前端工程師 Front-end Engineer',
#    'jobRole': '1',
#    'jobRo': '1',
#    'jobAddrNoDesc': '台北市信義區',
#    'jobAddress': '忠孝東路五段68號35樓',
#    'description': '工作內容\r\n\r\n- 維護公司現有網站平台\r\n- 參與部份新功能的開發\r\n- 提升平台 UI/UX\r\n\r\n\r\n能力需求\r\n\r\n- 熟悉 Vue.js 的開發\r\n- 對 UI/UX 有興趣\r\n- 樂於嘗試不同前端技術\r\n- 具備享受工作的能力\r\n\r\n\r\n主要開發環境 / 工具\r\n\r\n- Vue.js\r\n- Nuxt.js\r\n- Node.js\r\n- Vanilla.js\r\n- Typescript\r\n- SASS\r\n- PWA\r\n- Webpack\r\n- Storybook\r\n\r\n\r\n加分條件\r\n\r\n- Nuxt.js 實務經驗\r\n- Node.js 實務經驗',
#    'optionEdu': '學歷不拘',
#    'period': '00',
#    'periodDesc': '經歷不拘',
#    'applyCnt': '00008',
#    'applyDesc': '6~10人應徵',
#    'custNo': '130000000135977',
#    'custName': '大牛科技有限公司',
#    'coIndustry': '1006003001',
#    'coIndustryDesc': '廣告行銷公關業',
#    'salaryLow': '0000000',
#    'salaryHigh': '0000000',
#    'salaryDesc': '待遇面議',
#    's10': '10',
#    'appearDate': '20200916',
#    'appearDateDesc': '9/16',
#    'optionZone': '0',
#    'isApply': '0',
#    'applyDate': '',
#    'isSave': '0',
#    'descSnippet': '工作內容\r\n\r\n- 維護公司現有網站平台\r\n- 參與部份新功能的開發\r\n- 提升平台 UI/UX\r\n\r\n\r\n能力需求\r\n\r\n- 熟悉 Vue.js 的開發\r\n- 對 UI/UX 有興趣\r\n- 樂於嘗試不同前端技術\r\n- 具備享受工作的能力\r\n\r\n\r\n主要開發環境 / 工具\r\n\r\n- Vue.js\r\n- Nuxt.js\r\n- Node.js\r\n- Vanilla.js\r\n- Typescript\r\n- SASS\r\n- PWA\r\n- Webpack\r\n- Storybook\r\n\r\n\r\n加分條件\r\n\r\n- Nuxt.js 實務經驗\r\n- Node.js 實務經驗',
#    'tags': [],
#    'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6xkij?channel=104rpt&jobsource=apply_analyze',
#     'job': '//www.104.com.tw/job/6xkij?jobsource=n104bank2',
#     'cust': '//www.104.com.tw/company/1a2x6bkw89?jobsource=n104bank2'},
#    'jobsource': '',
#    'jobNameRaw': 'Vue 前端工程師 Front-end Engineer',
#    'custNameRaw': '大牛科技有限公司'}],
#  'count': ['10571', '10156', '198', '0', '59', '130', '28'],
#  'pageNo': 2,
#  'totalPage': 150,
#  'totalCount': 10156}

# %%
for job in j['data']['list']:
    break
job
# Out:
# {'jobType': '0',
#  'jobNo': '7840508',
#  'jobName': 'FPGA系統工程師',
#  'jobNameSnippet': 'FPGA系統工程師',
#  'jobRole': '1',
#  'jobRo': '1',
#  'jobAddrNoDesc': '台北市南港區',
#  'jobAddress': '園區街3-2號9樓(H棟)',
#  'description': '1. 熟悉 Verilog/VHDL 設計開發語言。\r\n2. 熟悉 Xilinx Vivado 開發環境佳。',
#  'optionEdu': '學歷不拘',
#  'period': '00',
#  'periodDesc': '經歷不拘',
#  'applyCnt': '00003',
#  'applyDesc': '0~5人應徵',
#  'custNo': '130000000066724',
#  'custName': '捷揚航電股份有限公司',
#  'coIndustry': '1001003001',
#  'coIndustryDesc': '電腦及其週邊設備製造業',
#  'salaryLow': '0000000',
#  'salaryHigh': '0000000',
#  'salaryDesc': '待遇面議',
#  's10': '10',
#  'appearDate': '20200909',
#  'appearDateDesc': '9/09',
#  'optionZone': '0',
#  'isApply': '0',
#  'applyDate': '',
#  'isSave': '0',
#  'descSnippet': '1. 熟悉 Verilog/VHDL 設計開發語言。\r\n2. 熟悉 Xilinx Vivado 開發環境佳。',
#  'tags': [],
#  'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/4o1rw?channel=104rpt&jobsource=apply_analyze',
#   'job': '//www.104.com.tw/job/4o1rw?jobsource=n104bank2',
#   'cust': '//www.104.com.tw/company/1a2x6bjesk?jobsource=n104bank2'},
#  'jobsource': '',
#  'jobNameRaw': 'FPGA系統工程師',
#  'custNameRaw': '捷揚航電股份有限公司'}

# %%
for k, v in job.items():
    try:
        print(v.split('\n')[0])
    except:
        print(v)
# Out:
# 0
# 11395097
# Sr. Security Architect
# Sr. Security Architect
# 1
# 1
# 台北市中山區
# 民生東路
# In this role, you will be responsible for designing and driving the adoption of security architectures for the KaiOS ecosystem. You will work with our hardware, software, and cloud services teams to ensure the proper security measures are designed and implemented accordingly.
# 學歷不拘
# 00
# 經歷不拘
# 00000
# 0~5人應徵
# 130000000113279
# KaiOS_台灣愷易科技有限公司
# 1001001002
# 電腦軟體服務業
# 0000000
# 0000000
# 待遇面議
# 10
# 20200911
# 9/11
# 0
# 0
#
# 0
# In this role, you will be responsible for designing and driving the adoption of security architectures for the KaiOS ecosystem. You will work with our hardware, software, and cloud services teams to ensure the proper security measures are designed and implemented accordingly.
# []
# {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6s8ih?channel=104rpt&jobsource=apply_analyze', 'job': '//www.104.com.tw/job/6s8ih?jobsource=n104bank2', 'cust': '//www.104.com.tw/company/1a2x6bkepr?jobsource=n104bank2'}
#
# Sr. Security Architect
# KaiOS_台灣愷易科技有限公司

# %%
item = {}

# %%
item['job_type'] = job['jobType']
item['job_no'] = job['jobNo']
item['job_name'] = job['jobName']
item['job_role'] = job['jobRole'] # 正職？
item['job_addr_dist'] = job['jobAddrNoDesc']
item['job_addr'] = job['jobAddrNoDesc'] + job['jobAddress']
item['job_desc'] = job['description']
item['education'] = job['optionEdu']
item['experience'] = job['period']
item['apply_count'] = job['applyCnt']
item['company_no'] = job['custNo']
item['company_name'] = job['custName']
item['indust_no'] = job['coIndustry']
item['industry_name'] = job['coIndustryDesc']
item['salary_low'] = job['salaryLow']
item['salary_high'] = job['salaryHigh']
item['s10'] = job['s10'] #?
item['update_date'] = job['appearDate']
item['optionZone'] = job['optionZone'] #?
item['job_tag'] = job['tags']

item
# Out:
# {'job_type': '0',
#  'job_no': '10799975',
#  'job_name': '網路行銷企畫',
#  'job_role': '1',
#  'job_addr_dist': '台北市信義區',
#  'job_addr': '台北市信義區光復南路491號',
#  'job_desc': '網站行銷企劃\r\n\r\n1.負責網站前後台功能及整體動線的企劃、執行與維護。\r\n2.規劃網路內容、服務及活動，並定期更新、維護及管理。\r\n3.負責網站內容招募、提案與執行。\r\n4.負責電子報、EDM及各種宣傳文案的設計、製作與發送。\r\n5.進行網路行銷及服務的成效追蹤。',
#  'education': '學歷不拘',
#  'experience': '00',
#  'apply_count': '00015',
#  'company_no': '130000000019299',
#  'company_name': '佺龍興業有限公司',
#  'indust_no': '1003001009',
#  'industry_name': '建材／傢俱批發業',
#  'salary_low': '0030000',
#  'salary_high': '0040000',
#  's10': '50',
#  'update_date': '20200827',
#  'optionZone': '0',
#  'job_tag': ['員工20人']}

# %%
import re

# %%
job['link']
# Out:
# {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6fhbb?channel=104rpt&jobsource=apply_analyze',
#  'job': '//www.104.com.tw/job/6fhbb?jobsource=n104bank2',
#  'cust': '//www.104.com.tw/company/1a2x6bie77?jobsource=n104bank2'}

# %%
company_link = job['link']['cust']
company_id = re.search('company/(.*)\?', company_link).group(1)
company_id
# Out:
# '1a2x6bie77'

# %%
# Out:
# absl-py==0.7.1
# alabaster==0.7.11
# anaconda-client==1.7.2
# anaconda-navigator==1.9.2
# anaconda-project==0.8.2
# aniso8601==4.1.0
# appdirs==1.4.3
# appnope==0.1.0
# appscript==1.0.1
# asn1crypto==0.24.0
# astor==0.7.1
# astroid==2.0.4
# astropy==3.0.4
# atomicwrites==1.2.1
# attrs==18.2.0
# Automat==0.7.0
# Babel==2.6.0
# backcall==0.1.0
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.6.3
# bitarray==0.8.3
# bkcharts==0.2
# blaze==0.11.3
# bleach==2.1.4
# bokeh==0.13.0
# boto==2.49.0
# boto3==1.9.174
# botocore==1.12.174
# Bottleneck==1.2.1
# certifi==2018.8.24
# cffi==1.11.5
# chardet==3.0.4
# click==6.7
# cloudpickle==0.5.5
# clyent==1.2.2
# colorama==0.3.9
# conda==4.5.11
# conda-build==3.15.1
# constantly==15.1.0
# contextlib2==0.5.5
# cryptography==2.3.1
# cssselect==1.0.3
# cycler==0.10.0
# Cython==0.28.5
# cytoolz==0.9.0.1
# dash==1.7.0
# dash-bootstrap-components==0.8.1
# dash-core-components==1.6.0
# dash-cytoscape==0.1.1
# dash-html-components==1.0.2
# dash-renderer==1.2.2
# dash-table==4.5.1
# dask==0.19.1
# datashape==0.5.4
# decorator==4.3.0
# defusedxml==0.5.0
# distributed==1.23.1
# docopt==0.6.2
# docutils==0.14
# entrypoints==0.2.3
# et-xmlfile==1.0.1
# fastcache==1.0.2
# feedfinder2==0.0.4
# feedparser==5.2.1
# filelock==3.0.8
# Flask==1.0.2
# Flask-Compress==1.4.0
# Flask-Cors==3.0.6
# flask-restplus==0.12.1
# Flask-Session==0.3.1
# Flask-SocketIO==3.0.1
# Flask-WTF==0.14.2
# future==0.17.1
# gast==0.2.2
# gensim==3.7.3
# gevent==1.3.6
# glob2==0.6
# gmpy2==2.0.8
# greenlet==0.4.15
# grpcio==1.20.1
# h5py==2.8.0
# heapdict==1.0.0
# html5lib==1.0.1
# hyperlink==18.0.0
# idna==2.7
# imageio==2.4.1
# imagesize==1.1.0
# imutils==0.5.2
# incremental==17.5.0
# ipykernel==4.9.0
# ipython==6.5.0
# ipython-genutils==0.2.0
# ipywidgets==7.4.1
# isort==4.3.4
# itsdangerous==0.24
# jdcal==1.4
# jedi==0.12.1
# jieba3k==0.35.1
# Jinja2==2.10
# jmespath==0.9.4
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.2.3
# jupyter-console==5.2.0
# jupyter-core==4.4.0
# jupyterlab==0.34.9
# jupyterlab-launcher==0.13.1
# kaggle==1.5.6
# Keras==2.2.4
# Keras-Applications==1.0.7
# Keras-Preprocessing==1.0.9
# keyring==13.2.1
# kiwisolver==1.0.1
# lazy-object-proxy==1.3.1
# llvmlite==0.24.0
# locket==0.2.0
# lxml==4.2.5
# Markdown==3.1
# MarkupSafe==1.0
# matplotlib==2.2.3
# mccabe==0.6.1
# mistune==0.8.3
# mkl-fft==1.0.4
# mkl-random==1.0.1
# mock==3.0.4
# more-itertools==4.3.0
# MouseInfo==0.1.3
# mpmath==1.0.0
# msgpack==0.5.6
# multipledispatch==0.6.0
# navigator-updater==0.2.1
# nbconvert==5.4.0
# nbformat==4.4.0
# nested-lookup==0.2.19
# networkx==2.1
# newspaper3k==0.2.8
# nltk==3.3
# nose==1.3.7
# notebook==5.6.0
# numba==0.39.0
# numexpr==2.6.8
# numpy==1.16.3
# numpydoc==0.8.0
# odo==0.5.1
# olefile==0.46
# opencv-python==3.4.5.20
# openpyxl==2.5.6
# packaging==17.1
# pandas==0.23.4
# pandocfilters==1.4.2
# parsel==1.5.0
# parso==0.3.1
# partd==0.3.8
# path.py==11.1.0
# pathlib2==2.3.2
# patsy==0.5.0
# pep8==1.7.1
# pexpect==4.6.0
# pickleshare==0.7.4
# pika==1.1.0
# Pillow==5.2.0
# pipreqs==0.4.10
# pkginfo==1.4.2
# plotly==4.1.1
# pluggy==0.7.1
# ply==3.11
# prometheus-client==0.3.1
# prompt-toolkit==1.0.15
# Protego==0.1.16
# protobuf==3.7.1
# psutil==5.4.7
# ptyprocess==0.6.0
# py==1.6.0
# pyasn1==0.4.4
# pyasn1-modules==0.2.2
# PyAutoGUI==0.9.50
# pycodestyle==2.4.0
# pycosat==0.6.3
# pycparser==2.18
# pycrypto==2.6.1
# pycurl==7.43.0.2
# PyDispatcher==2.0.5
# pyflakes==2.0.0
# PyGetWindow==0.0.8
# Pygments==2.2.0
# PyHamcrest==2.0.0
# pylint==2.1.1
# pymongo==3.7.2
# PyMsgBox==1.0.8
# pyobjc==6.2.1
# pyobjc-core==6.2.1
# pyobjc-framework-Accounts==6.2.1
# pyobjc-framework-AddressBook==6.2.1
# pyobjc-framework-AdSupport==6.2.1
# pyobjc-framework-AppleScriptKit==6.2.1
# pyobjc-framework-AppleScriptObjC==6.2.1
# pyobjc-framework-ApplicationServices==6.2.1
# pyobjc-framework-Automator==6.2.1
# pyobjc-framework-AVFoundation==6.2.1
# pyobjc-framework-AVKit==6.2.1
# pyobjc-framework-BusinessChat==6.2.1
# pyobjc-framework-CalendarStore==6.2.1
# pyobjc-framework-CFNetwork==6.2.1
# pyobjc-framework-CloudKit==6.2.1
# pyobjc-framework-Cocoa==6.2.1
# pyobjc-framework-Collaboration==6.2.1
# pyobjc-framework-ColorSync==6.2.1
# pyobjc-framework-Contacts==6.2.1
# pyobjc-framework-ContactsUI==6.2.1
# pyobjc-framework-CoreAudio==6.2.1
# pyobjc-framework-CoreAudioKit==6.2.1
# pyobjc-framework-CoreBluetooth==6.2.1
# pyobjc-framework-CoreData==6.2.1
# pyobjc-framework-CoreLocation==6.2.1
# pyobjc-framework-CoreMedia==6.2.1
# pyobjc-framework-CoreMediaIO==6.2.1
# pyobjc-framework-CoreML==6.2.1
# pyobjc-framework-CoreServices==6.2.1
# pyobjc-framework-CoreSpotlight==6.2.1
# pyobjc-framework-CoreText==6.2.1
# pyobjc-framework-CoreWLAN==6.2.1
# pyobjc-framework-CryptoTokenKit==6.2.1
# pyobjc-framework-DictionaryServices==6.2.1
# pyobjc-framework-DiscRecording==6.2.1
# pyobjc-framework-DiscRecordingUI==6.2.1
# pyobjc-framework-DiskArbitration==6.2.1
# pyobjc-framework-DVDPlayback==6.2.1
# pyobjc-framework-EventKit==6.2.1
# pyobjc-framework-ExceptionHandling==6.2.1
# pyobjc-framework-ExternalAccessory==6.2.1
# pyobjc-framework-FinderSync==6.2.1
# pyobjc-framework-FSEvents==6.2.1
# pyobjc-framework-GameCenter==6.2.1
# pyobjc-framework-GameController==6.2.1
# pyobjc-framework-GameKit==6.2.1
# pyobjc-framework-GameplayKit==6.2.1
# pyobjc-framework-ImageCaptureCore==6.2.1
# pyobjc-framework-IMServicePlugIn==6.2.1
# pyobjc-framework-InputMethodKit==6.2.1
# pyobjc-framework-InstallerPlugins==6.2.1
# pyobjc-framework-InstantMessage==6.2.1
# pyobjc-framework-Intents==6.2.1
# pyobjc-framework-IOSurface==6.2.1
# pyobjc-framework-iTunesLibrary==6.2.1
# pyobjc-framework-LatentSemanticMapping==6.2.1
# pyobjc-framework-LaunchServices==6.2.1
# pyobjc-framework-libdispatch==6.2.1
# pyobjc-framework-LocalAuthentication==6.2.1
# pyobjc-framework-MapKit==6.2.1
# pyobjc-framework-MediaAccessibility==6.2.1
# pyobjc-framework-MediaLibrary==6.2.1
# pyobjc-framework-MediaPlayer==6.2.1
# pyobjc-framework-MediaToolbox==6.2.1
# pyobjc-framework-Metal==6.2.1
# pyobjc-framework-MetalKit==6.2.1
# pyobjc-framework-ModelIO==6.2.1
# pyobjc-framework-MultipeerConnectivity==6.2.1
# pyobjc-framework-NaturalLanguage==6.2.1
# pyobjc-framework-NetFS==6.2.1
# pyobjc-framework-Network==6.2.1
# pyobjc-framework-NetworkExtension==6.2.1
# pyobjc-framework-NotificationCenter==6.2.1
# pyobjc-framework-OpenDirectory==6.2.1
# pyobjc-framework-OSAKit==6.2.1
# pyobjc-framework-Photos==6.2.1
# pyobjc-framework-PhotosUI==6.2.1
# pyobjc-framework-PreferencePanes==6.2.1
# pyobjc-framework-QTKit==6.2.1
# pyobjc-framework-Quartz==6.2.1
# pyobjc-framework-SafariServices==6.2.1
# pyobjc-framework-SceneKit==6.2.1
# pyobjc-framework-ScreenSaver==6.2.1
# pyobjc-framework-ScriptingBridge==6.2.1
# pyobjc-framework-SearchKit==6.2.1
# pyobjc-framework-Security==6.2.1
# pyobjc-framework-SecurityFoundation==6.2.1
# pyobjc-framework-SecurityInterface==6.2.1
# pyobjc-framework-ServiceManagement==6.2.1
# pyobjc-framework-Social==6.2.1
# pyobjc-framework-SpriteKit==6.2.1
# pyobjc-framework-StoreKit==6.2.1
# pyobjc-framework-SyncServices==6.2.1
# pyobjc-framework-SystemConfiguration==6.2.1
# pyobjc-framework-UserNotifications==6.2.1
# pyobjc-framework-VideoSubscriberAccount==6.2.1
# pyobjc-framework-VideoToolbox==6.2.1
# pyobjc-framework-Vision==6.2.1
# pyobjc-framework-WebKit==6.2.1
# pyodbc==4.0.24
# pyOpenSSL==18.0.0
# pyparsing==2.2.0
# pyperclip==1.8.0
# PyRect==0.1.4
# PyScreeze==0.1.26
# PySocks==1.6.8
# pytest==3.8.0
# pytest-arraydiff==0.2
# pytest-astropy==0.4.0
# pytest-doctestplus==0.1.3
# pytest-openfiles==0.3.0
# pytest-remotedata==0.3.0
# pytest-runner==4.2
# python-dateutil==2.7.3
# python-engineio==3.11.2
# python-Levenshtein==0.12.0
# python-slugify==4.0.0
# python-socketio==1.9.0
# PyTweening==1.0.3
# pytz==2018.5
# PyWavelets==1.0.0
# PyYAML==5.1
# pyzmq==17.1.2
# QtAwesome==0.4.4
# qtconsole==4.4.1
# QtPy==1.5.0
# queuelib==1.5.0
# requests==2.19.1
# requests-file==1.4.3
# retrying==1.3.3
# rope==0.11.0
# ruamel-yaml==0.15.46
# rubicon-objc==0.3.1
# s3transfer==0.2.1
# scikit-image==0.14.0
# scikit-learn==0.19.2
# scipy==1.3.0
# Scrapy==1.8.0
# seaborn==0.9.0
# selenium==3.14.1
# Send2Trash==1.5.0
# service-identity==17.0.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.12.0
# smart-open==1.8.4
# snowballstemmer==1.2.1
# sortedcollections==1.0.1
# sortedcontainers==2.0.5
# Sphinx==1.7.9
# sphinxcontrib-websupport==1.1.0
# spyder==3.3.1
# spyder-kernels==0.2.6
# SQLAlchemy==1.2.11
# statsmodels==0.9.0
# sympy==1.2
# tables==3.4.4
# tblib==1.3.2
# tensorboard==1.13.1
# tensorflow==1.13.1
# tensorflow-estimator==1.13.0
# termcolor==1.1.0
# terminado==0.8.1
# testpath==0.3.1
# text-unidecode==1.3
# Theano==1.0.4
# tinysegmenter==0.3
# tldextract==2.2.0
# toolz==0.9.0
# tornado==5.1
# tqdm==4.26.0
# traitlets==4.3.2
# Twisted==18.7.0
# unicodecsv==0.14.1
# urllib3==1.23
# virtualenv==16.4.0
# w3lib==1.19.0
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.14.1
# widgetsnbextension==3.4.1
# word2vec==0.10.2
# wrapt==1.10.11
# WTForms==2.2.1
# xgboost==0.82
# xlrd==1.1.0
# XlsxWriter==1.1.0
# xlwings==0.11.8
# xlwt==1.3.0
# yarg==0.1.9
# zict==0.1.3
# zope.interface==4.5.0

# %%
# Out:
# True
